# %%
import numpy as np
import pandas as pd
import chronos
# Out:
# 2025-07-21 18:58:53.595195: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-21 18:58:53.692431: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
#!pip3.10 install crispr_chronos

# %%
ParalogRawCounts = pd.read_csv("/home/ubuntu/paralog/ras_screens/2025-07-21_pooled_counts.csv", index_col=0)
ParalogRawCountsPDNA = pd.read_csv("/home/ubuntu/paralog/ras_screens/2025-07-21_pdna_counts.csv", index_col=0)

# %%
ParalogRawCountsPDNA
# Out:
#                     RAS-pDNA
# AAVS1_L5_ABCB7_R4       2799
# AAVS1_L5_ABCB7_R6       2236
# AAVS1_L5_ABCF1_R2       2033
# AAVS1_L5_ABCF1_R4       1951
# AAVS1_L5_ABL1_R2        2996
# ...                      ...
# YWHAZ_L3_YWHAG_R6       2988
# YY1_L1_AAVS1_R2         2470
# YY1_L5_AAVS1_R2         2988
# ZNF143_L1_AAVS1_R2      4121
# ZNF143_L3_AAVS1_R2      3235
#
# [84200 rows x 1 columns]

# %%
ParalogRawCounts
# Out:
#                     PACADD188-Cas9VY-Ras-RepNA-P5(D25)  \
# AAVS1_L5_ABCB7_R4                                    1
# AAVS1_L5_ABCB7_R6                                   94
# AAVS1_L5_ABCF1_R2                                   28
# AAVS1_L5_ABCF1_R4                                   98
# AAVS1_L5_ABL1_R2                                   409
# ...                                                ...
# YWHAZ_L3_YWHAG_R6                                  582
# YY1_L1_AAVS1_R2                                     39
# YY1_L5_AAVS1_R2                                     93
# ZNF143_L1_AAVS1_R2                                 218
# ZNF143_L3_AAVS1_R2                                 122
#
#                     PANC0203_500x-Cas9VY-RAS-RepNA-P5(D17)  \
# AAVS1_L5_ABCB7_R4                                      185
# AAVS1_L5_ABCB7_R6                                      258
# AAVS1_L5_ABCF1_R2                                      132
# AAVS1_L5_ABCF1_R4                                      111
# ...

# %%
pd.set_option("display.max.rows", 500)

# %%
from taigapy import default_tc as tc

# %%
new_dataset_id = tc.create_dataset(
    "RASScreen07212025",
    dataset_description = "Adding onto the RAS screen dataset with plates WRS00063 -- PACADD188",
    upload_files = [
        {
            "path" : "/home/ubuntu/paralog/ras_screens/2025-07-21_pooled_counts.csv",
            "name" : "RASRawCounts",
            "format": "NumericMatrixCSV",
            "encoding" : "utf-8"
        },
        {
            "path" : "/home/ubuntu/paralog/ras_screens/2025-07-21_pdna_counts.csv",
            "name" : "RASRawCountspDNA",
            "format": "NumericMatrixCSV",
            "encoding" : "utf-8"
        }
    ],
    folder_id =  "c0180df27c8a4b7ea247527d42484beb"
)
# Out:
# /home/ubuntu/miniconda3/envs/paralog/lib/python3.10/site-packages/taigapy/client.py:497: UserWarning: upload_async == True but parallel uploads are no longer supported. Parallel uploads were unreliable and have been disabled.
#   warnings.warn(f"upload_async == {upload_async} but parallel uploads are no longer supported. Parallel uploads were unreliable and have been disabled.")
# Finished uploading RASRawCounts to S3
# Uploading RASRawCounts to Taiga
# Finished uploading RASRawCounts to Taiga
# Finished uploading RASRawCountspDNA to S3
# Uploading RASRawCountspDNA to Taiga
# Finished uploading RASRawCountspDNA to Taiga
# Dataset created. Access it directly with this url: https://cds.team/taiga/dataset/b9c3bed403d944f1ab3f3ed91e7e8f71
