# %%
import numpy as np
import pandas as pd
import chronos
# Out:
# 2025-01-07 17:29:47.712656: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-07 17:29:48.087597: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
#!pip3.10 install crispr_chronos

# %%
ParalogRawCounts = pd.read_csv("/home/ubuntu/paralog/2025-01-07_pooled_counts.csv", index_col=0)
ParalogRawCountsPDNA = pd.read_csv("/home/ubuntu/paralog/2025-01-07_pdna_counts.csv", index_col=0)

# %%
ParalogRawCountsPDNA
# Out:
#                     RAS-pDNA
# AAVS1_L5_ABCB7_R4       2799
# AAVS1_L5_ABCB7_R6       2236
# AAVS1_L5_ABCF1_R2       2033
# AAVS1_L5_ABCF1_R4       1951
# AAVS1_L5_ABL1_R2        2996
# ...                      ...
# YWHAZ_L3_YWHAG_R6       2988
# YY1_L1_AAVS1_R2         2470
# YY1_L5_AAVS1_R2         2988
# ZNF143_L1_AAVS1_R2      4121
# ZNF143_L3_AAVS1_R2      3235
#
# [84200 rows x 1 columns]

# %%
ParalogRawCounts
# Out:
#                     HPAFII_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                    279
# AAVS1_L5_ABCB7_R6                                     21
# AAVS1_L5_ABCF1_R2                                     24
# AAVS1_L5_ABCF1_R4                                    701
# AAVS1_L5_ABL1_R2                                    2694
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                    169
# YY1_L1_AAVS1_R2                                      281
# YY1_L5_AAVS1_R2                                      117
# ZNF143_L1_AAVS1_R2                                   328
# ZNF143_L3_AAVS1_R2                                   893
#
#                     BXPC3_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                   431
# AAVS1_L5_ABCB7_R6                                   428
# AAVS1_L5_ABCF1_R2                                   336
# ...

# %%
pd.set_option("display.max.rows", 500)

# %%
from taigapy import default_tc as tc

# %%
new_dataset_id = tc.create_dataset(
    "RASScreen01072025",
    dataset_description = "Creating the RAS screen dataset with WRS00039, WRS00040, WRS00046, WRS00047, WRS00052",
    upload_files = [
        {
            "path" : "/home/ubuntu/paralog/2025-01-07_pooled_counts.csv",
            "name" : "RASRawCounts",
            "format": "NumericMatrixCSV",
            "encoding" : "utf-8"
        },
        {
            "path" : "/home/ubuntu/paralog/2025-01-07_pdna_counts.csv",
            "name" : "RASRawCountspDNA",
            "format": "NumericMatrixCSV",
            "encoding" : "utf-8"
        }
    ],
    folder_id =  "c0180df27c8a4b7ea247527d42484beb"
)
# Out:
# /home/ubuntu/miniconda3/envs/paralog/lib/python3.10/site-packages/taigapy/client.py:497: UserWarning: upload_async == True but parallel uploads are no longer supported. Parallel uploads were unreliable and have been disabled.
#   warnings.warn(f"upload_async == {upload_async} but parallel uploads are no longer supported. Parallel uploads were unreliable and have been disabled.")
# Finished uploading RASRawCounts to S3
# Uploading RASRawCounts to Taiga
# Finished uploading RASRawCounts to Taiga
# Finished uploading RASRawCountspDNA to S3
# Uploading RASRawCountspDNA to Taiga
# Finished uploading RASRawCountspDNA to Taiga
# Dataset created. Access it directly with this url: https://cds.team/taiga/dataset/1ea951621558497ab182b3ed7dc15ecd
