# %%
import numpy as np
import pandas as pd
import chronos
# Out:
# 2025-02-07 16:15:42.326028: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-07 16:15:42.414165: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
from taigapy import TaigaClient
tc = TaigaClient()
RASRawCounts = tc.get(name='rasscreen02062025-6bdb', file='RASRawCounts')
RASRawCountspDNA= tc.get(name='rasscreen02062025-6bdb', file='RASRawCountspDNA')
# Out:
# No dataset version provided. Using version 3.
# No dataset version provided. Using version 3.

# %%
RASRawCounts
# Out:
#                     SNU1079_250x-Cas9VY-RAS-RepNA-P5(D25)  \
# AAVS1_L5_ABCB7_R4                                  5595.0
# AAVS1_L5_ABCB7_R6                                  5136.0
# AAVS1_L5_ABCF1_R2                                  1745.0
# AAVS1_L5_ABCF1_R4                                  1705.0
# AAVS1_L5_ABL1_R2                                   3581.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                  2969.0
# YY1_L1_AAVS1_R2                                    7338.0
# YY1_L5_AAVS1_R2                                     706.0
# ZNF143_L1_AAVS1_R2                                 6936.0
# ZNF143_L3_AAVS1_R2                                 5058.0
#
#                     COLO678_250x-Cas9VY-RAS-RepNA-P5(D25)  \
# AAVS1_L5_ABCB7_R4                                   321.0
# AAVS1_L5_ABCB7_R6                                   515.0
# AAVS1_L5_ABCF1_R2                                   238.0
# AAVS1_L5_ABCF1_R4                                   410.0
# AAVS1_L5_ABL1_R2                                    886.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                  1066.0
# YY1_L1_AAVS1_R2                                     126.0
# YY1_L5_AAVS1_R2                                      54.0
# ZNF143_L1_AAVS1_R2                                 1522.0
# ZNF143_L3_AAVS1_R2                                 1039.0
#
#                     SNU410_125x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                  114.0
# AAVS1_L5_ABCB7_R6                                  111.0
# AAVS1_L5_ABCF1_R2                                   67.0
# AAVS1_L5_ABCF1_R4                                  329.0
# AAVS1_L5_ABL1_R2                                   876.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                  691.0
# YY1_L1_AAVS1_R2                                     91.0
# YY1_L5_AAVS1_R2                                    901.0
# ZNF143_L1_AAVS1_R2                                 426.0
# ZNF143_L3_AAVS1_R2                                 820.0
#
#                     BXPC3_125x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                 663.0
# AAVS1_L5_ABCB7_R6                                 194.0
# AAVS1_L5_ABCF1_R2                                 127.0
# AAVS1_L5_ABCF1_R4                                 251.0
# AAVS1_L5_ABL1_R2                                 1051.0
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                                 436.0
# YY1_L1_AAVS1_R2                                   239.0
# YY1_L5_AAVS1_R2                                   331.0
# ZNF143_L1_AAVS1_R2                                976.0
# ZNF143_L3_AAVS1_R2                               1025.0
#
#                     SNU478_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                    0.0
# AAVS1_L5_ABCB7_R6                                    1.0
# AAVS1_L5_ABCF1_R2                                   70.0
# AAVS1_L5_ABCF1_R4                                  135.0
# AAVS1_L5_ABL1_R2                                   451.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                  525.0
# YY1_L1_AAVS1_R2                                     19.0
# YY1_L5_AAVS1_R2                                    323.0
# ZNF143_L1_AAVS1_R2                                 288.0
# ZNF143_L3_AAVS1_R2                                 595.0
#
#                     HCT15_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                  79.0
# AAVS1_L5_ABCB7_R6                                  34.0
# AAVS1_L5_ABCF1_R2                                  54.0
# AAVS1_L5_ABCF1_R4                                 185.0
# AAVS1_L5_ABL1_R2                                 1256.0
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                                 654.0
# YY1_L1_AAVS1_R2                                   140.0
# YY1_L5_AAVS1_R2                                    80.0
# ZNF143_L1_AAVS1_R2                               1143.0
# ZNF143_L3_AAVS1_R2                                552.0
#
#                     COLO205_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                   177.0
# AAVS1_L5_ABCB7_R6                                   138.0
# AAVS1_L5_ABCF1_R2                                   224.0
# AAVS1_L5_ABCF1_R4                                   145.0
# AAVS1_L5_ABL1_R2                                    591.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                   183.0
# YY1_L1_AAVS1_R2                                     182.0
# YY1_L5_AAVS1_R2                                     110.0
# ZNF143_L1_AAVS1_R2                                  872.0
# ZNF143_L3_AAVS1_R2                                  427.0
#
#                     HPAFII_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                  279.0
# AAVS1_L5_ABCB7_R6                                   21.0
# AAVS1_L5_ABCF1_R2                                   24.0
# AAVS1_L5_ABCF1_R4                                  701.0
# AAVS1_L5_ABL1_R2                                  2694.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                  169.0
# YY1_L1_AAVS1_R2                                    281.0
# YY1_L5_AAVS1_R2                                    117.0
# ZNF143_L1_AAVS1_R2                                 328.0
# ZNF143_L3_AAVS1_R2                                 893.0
#
#                     BXPC3_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                 431.0
# AAVS1_L5_ABCB7_R6                                 428.0
# AAVS1_L5_ABCF1_R2                                 336.0
# AAVS1_L5_ABCF1_R4                                 491.0
# AAVS1_L5_ABL1_R2                                 1185.0
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                                 938.0
# YY1_L1_AAVS1_R2                                   243.0
# YY1_L5_AAVS1_R2                                   532.0
# ZNF143_L1_AAVS1_R2                                888.0
# ZNF143_L3_AAVS1_R2                               1148.0
#
#                     BXPC3_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                 440.0
# AAVS1_L5_ABCB7_R6                                 263.0
# AAVS1_L5_ABCF1_R2                                 221.0
# AAVS1_L5_ABCF1_R4                                 165.0
# AAVS1_L5_ABL1_R2                                  957.0
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                                 429.0
# YY1_L1_AAVS1_R2                                   296.0
# YY1_L5_AAVS1_R2                                   575.0
# ZNF143_L1_AAVS1_R2                               1219.0
# ZNF143_L3_AAVS1_R2                                862.0
#
#                     SNU410_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                  275.0
# AAVS1_L5_ABCB7_R6                                  635.0
# AAVS1_L5_ABCF1_R2                                  746.0
# AAVS1_L5_ABCF1_R4                                  963.0
# AAVS1_L5_ABL1_R2                                  2533.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                 3327.0
# YY1_L1_AAVS1_R2                                    525.0
# YY1_L5_AAVS1_R2                                   1017.0
# ZNF143_L1_AAVS1_R2                                1090.0
# ZNF143_L3_AAVS1_R2                                1667.0
#
#                     SNU410_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                   57.0
# AAVS1_L5_ABCB7_R6                                   30.0
# AAVS1_L5_ABCF1_R2                                  166.0
# AAVS1_L5_ABCF1_R4                                  147.0
# AAVS1_L5_ABL1_R2                                  1396.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                 2696.0
# YY1_L1_AAVS1_R2                                    377.0
# YY1_L5_AAVS1_R2                                    392.0
# ZNF143_L1_AAVS1_R2                                 878.0
# ZNF143_L3_AAVS1_R2                                 712.0
#
#                     IPC298_500x-Cas9311-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                     1.0
# AAVS1_L5_ABCB7_R6                                     0.0
# AAVS1_L5_ABCF1_R2                                    54.0
# AAVS1_L5_ABCF1_R4                                   510.0
# AAVS1_L5_ABL1_R2                                    671.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                    79.0
# YY1_L1_AAVS1_R2                                     124.0
# YY1_L5_AAVS1_R2                                     101.0
# ZNF143_L1_AAVS1_R2                                  129.0
# ZNF143_L3_AAVS1_R2                                  551.0
#
#                     IPC298_250x-Cas9311-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                     0.0
# AAVS1_L5_ABCB7_R6                                     0.0
# AAVS1_L5_ABCF1_R2                                    13.0
# AAVS1_L5_ABCF1_R4                                    64.0
# AAVS1_L5_ABL1_R2                                    325.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                   382.0
# YY1_L1_AAVS1_R2                                      20.0
# YY1_L5_AAVS1_R2                                      65.0
# ZNF143_L1_AAVS1_R2                                  134.0
# ZNF143_L3_AAVS1_R2                                  317.0
#
#                     PANC1-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                            142.0
# AAVS1_L5_ABCB7_R6                            182.0
# AAVS1_L5_ABCF1_R2                            283.0
# AAVS1_L5_ABCF1_R4                            261.0
# AAVS1_L5_ABL1_R2                             402.0
# ...                                            ...
# YWHAZ_L3_YWHAG_R6                            368.0
# YY1_L1_AAVS1_R2                               30.0
# YY1_L5_AAVS1_R2                              117.0
# ZNF143_L1_AAVS1_R2                           489.0
# ZNF143_L3_AAVS1_R2                           310.0
#
#                     PANC0203-Cas9VY-RAS-RepNA-P4(D21)
# AAVS1_L5_ABCB7_R4                               260.0
# AAVS1_L5_ABCB7_R6                               468.0
# AAVS1_L5_ABCF1_R2                               133.0
# AAVS1_L5_ABCF1_R4                               284.0
# AAVS1_L5_ABL1_R2                               1542.0
# ...                                               ...
# YWHAZ_L3_YWHAG_R6                              1158.0
# YY1_L1_AAVS1_R2                                 304.0
# YY1_L5_AAVS1_R2                                 313.0
# ZNF143_L1_AAVS1_R2                              829.0
# ZNF143_L3_AAVS1_R2                              792.0
#
# [84200 rows x 16 columns]

# %%
RASRawCountspDNA
# Out:
#                     RAS-pDNA
# AAVS1_L5_ABCB7_R4     2799.0
# AAVS1_L5_ABCB7_R6     2236.0
# AAVS1_L5_ABCF1_R2     2033.0
# AAVS1_L5_ABCF1_R4     1951.0
# AAVS1_L5_ABL1_R2      2996.0
# ...                      ...
# YWHAZ_L3_YWHAG_R6     2988.0
# YY1_L1_AAVS1_R2       2470.0
# YY1_L5_AAVS1_R2       2988.0
# ZNF143_L1_AAVS1_R2    4121.0
# ZNF143_L3_AAVS1_R2    3235.0
#
# [84200 rows x 1 columns]

# %%
RASFullCounts = RASRawCounts.merge(RASRawCountspDNA, left_index=True, right_index=True)
RASFullCounts
# Out:
#                     SNU1079_250x-Cas9VY-RAS-RepNA-P5(D25)  \
# AAVS1_L5_ABCB7_R4                                  5595.0
# AAVS1_L5_ABCB7_R6                                  5136.0
# AAVS1_L5_ABCF1_R2                                  1745.0
# AAVS1_L5_ABCF1_R4                                  1705.0
# AAVS1_L5_ABL1_R2                                   3581.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                  2969.0
# YY1_L1_AAVS1_R2                                    7338.0
# YY1_L5_AAVS1_R2                                     706.0
# ZNF143_L1_AAVS1_R2                                 6936.0
# ZNF143_L3_AAVS1_R2                                 5058.0
#
#                     COLO678_250x-Cas9VY-RAS-RepNA-P5(D25)  \
# AAVS1_L5_ABCB7_R4                                   321.0
# AAVS1_L5_ABCB7_R6                                   515.0
# AAVS1_L5_ABCF1_R2                                   238.0
# AAVS1_L5_ABCF1_R4                                   410.0
# AAVS1_L5_ABL1_R2                                    886.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                  1066.0
# YY1_L1_AAVS1_R2                                     126.0
# YY1_L5_AAVS1_R2                                      54.0
# ZNF143_L1_AAVS1_R2                                 1522.0
# ZNF143_L3_AAVS1_R2                                 1039.0
#
#                     SNU410_125x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                  114.0
# AAVS1_L5_ABCB7_R6                                  111.0
# AAVS1_L5_ABCF1_R2                                   67.0
# AAVS1_L5_ABCF1_R4                                  329.0
# AAVS1_L5_ABL1_R2                                   876.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                  691.0
# YY1_L1_AAVS1_R2                                     91.0
# YY1_L5_AAVS1_R2                                    901.0
# ZNF143_L1_AAVS1_R2                                 426.0
# ZNF143_L3_AAVS1_R2                                 820.0
#
#                     BXPC3_125x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                 663.0
# AAVS1_L5_ABCB7_R6                                 194.0
# AAVS1_L5_ABCF1_R2                                 127.0
# AAVS1_L5_ABCF1_R4                                 251.0
# AAVS1_L5_ABL1_R2                                 1051.0
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                                 436.0
# YY1_L1_AAVS1_R2                                   239.0
# YY1_L5_AAVS1_R2                                   331.0
# ZNF143_L1_AAVS1_R2                                976.0
# ZNF143_L3_AAVS1_R2                               1025.0
#
#                     SNU478_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                    0.0
# AAVS1_L5_ABCB7_R6                                    1.0
# AAVS1_L5_ABCF1_R2                                   70.0
# AAVS1_L5_ABCF1_R4                                  135.0
# AAVS1_L5_ABL1_R2                                   451.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                  525.0
# YY1_L1_AAVS1_R2                                     19.0
# YY1_L5_AAVS1_R2                                    323.0
# ZNF143_L1_AAVS1_R2                                 288.0
# ZNF143_L3_AAVS1_R2                                 595.0
#
#                     HCT15_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                  79.0
# AAVS1_L5_ABCB7_R6                                  34.0
# AAVS1_L5_ABCF1_R2                                  54.0
# AAVS1_L5_ABCF1_R4                                 185.0
# AAVS1_L5_ABL1_R2                                 1256.0
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                                 654.0
# YY1_L1_AAVS1_R2                                   140.0
# YY1_L5_AAVS1_R2                                    80.0
# ZNF143_L1_AAVS1_R2                               1143.0
# ZNF143_L3_AAVS1_R2                                552.0
#
#                     COLO205_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                   177.0
# AAVS1_L5_ABCB7_R6                                   138.0
# AAVS1_L5_ABCF1_R2                                   224.0
# AAVS1_L5_ABCF1_R4                                   145.0
# AAVS1_L5_ABL1_R2                                    591.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                   183.0
# YY1_L1_AAVS1_R2                                     182.0
# YY1_L5_AAVS1_R2                                     110.0
# ZNF143_L1_AAVS1_R2                                  872.0
# ZNF143_L3_AAVS1_R2                                  427.0
#
#                     HPAFII_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                  279.0
# AAVS1_L5_ABCB7_R6                                   21.0
# AAVS1_L5_ABCF1_R2                                   24.0
# AAVS1_L5_ABCF1_R4                                  701.0
# AAVS1_L5_ABL1_R2                                  2694.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                  169.0
# YY1_L1_AAVS1_R2                                    281.0
# YY1_L5_AAVS1_R2                                    117.0
# ZNF143_L1_AAVS1_R2                                 328.0
# ZNF143_L3_AAVS1_R2                                 893.0
#
#                     BXPC3_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                 431.0
# AAVS1_L5_ABCB7_R6                                 428.0
# AAVS1_L5_ABCF1_R2                                 336.0
# AAVS1_L5_ABCF1_R4                                 491.0
# AAVS1_L5_ABL1_R2                                 1185.0
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                                 938.0
# YY1_L1_AAVS1_R2                                   243.0
# YY1_L5_AAVS1_R2                                   532.0
# ZNF143_L1_AAVS1_R2                                888.0
# ZNF143_L3_AAVS1_R2                               1148.0
#
#                     BXPC3_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                 440.0
# AAVS1_L5_ABCB7_R6                                 263.0
# AAVS1_L5_ABCF1_R2                                 221.0
# AAVS1_L5_ABCF1_R4                                 165.0
# AAVS1_L5_ABL1_R2                                  957.0
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                                 429.0
# YY1_L1_AAVS1_R2                                   296.0
# YY1_L5_AAVS1_R2                                   575.0
# ZNF143_L1_AAVS1_R2                               1219.0
# ZNF143_L3_AAVS1_R2                                862.0
#
#                     SNU410_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                  275.0
# AAVS1_L5_ABCB7_R6                                  635.0
# AAVS1_L5_ABCF1_R2                                  746.0
# AAVS1_L5_ABCF1_R4                                  963.0
# AAVS1_L5_ABL1_R2                                  2533.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                 3327.0
# YY1_L1_AAVS1_R2                                    525.0
# YY1_L5_AAVS1_R2                                   1017.0
# ZNF143_L1_AAVS1_R2                                1090.0
# ZNF143_L3_AAVS1_R2                                1667.0
#
#                     SNU410_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                   57.0
# AAVS1_L5_ABCB7_R6                                   30.0
# AAVS1_L5_ABCF1_R2                                  166.0
# AAVS1_L5_ABCF1_R4                                  147.0
# AAVS1_L5_ABL1_R2                                  1396.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                 2696.0
# YY1_L1_AAVS1_R2                                    377.0
# YY1_L5_AAVS1_R2                                    392.0
# ZNF143_L1_AAVS1_R2                                 878.0
# ZNF143_L3_AAVS1_R2                                 712.0
#
#                     IPC298_500x-Cas9311-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                     1.0
# AAVS1_L5_ABCB7_R6                                     0.0
# AAVS1_L5_ABCF1_R2                                    54.0
# AAVS1_L5_ABCF1_R4                                   510.0
# AAVS1_L5_ABL1_R2                                    671.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                    79.0
# YY1_L1_AAVS1_R2                                     124.0
# YY1_L5_AAVS1_R2                                     101.0
# ZNF143_L1_AAVS1_R2                                  129.0
# ZNF143_L3_AAVS1_R2                                  551.0
#
#                     IPC298_250x-Cas9311-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                     0.0
# AAVS1_L5_ABCB7_R6                                     0.0
# AAVS1_L5_ABCF1_R2                                    13.0
# AAVS1_L5_ABCF1_R4                                    64.0
# AAVS1_L5_ABL1_R2                                    325.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                   382.0
# YY1_L1_AAVS1_R2                                      20.0
# YY1_L5_AAVS1_R2                                      65.0
# ZNF143_L1_AAVS1_R2                                  134.0
# ZNF143_L3_AAVS1_R2                                  317.0
#
#                     PANC1-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                            142.0
# AAVS1_L5_ABCB7_R6                            182.0
# AAVS1_L5_ABCF1_R2                            283.0
# AAVS1_L5_ABCF1_R4                            261.0
# AAVS1_L5_ABL1_R2                             402.0
# ...                                            ...
# YWHAZ_L3_YWHAG_R6                            368.0
# YY1_L1_AAVS1_R2                               30.0
# YY1_L5_AAVS1_R2                              117.0
# ZNF143_L1_AAVS1_R2                           489.0
# ZNF143_L3_AAVS1_R2                           310.0
#
#                     PANC0203-Cas9VY-RAS-RepNA-P4(D21)  RAS-pDNA
# AAVS1_L5_ABCB7_R4                               260.0    2799.0
# AAVS1_L5_ABCB7_R6                               468.0    2236.0
# AAVS1_L5_ABCF1_R2                               133.0    2033.0
# AAVS1_L5_ABCF1_R4                               284.0    1951.0
# AAVS1_L5_ABL1_R2                               1542.0    2996.0
# ...                                               ...       ...
# YWHAZ_L3_YWHAG_R6                              1158.0    2988.0
# YY1_L1_AAVS1_R2                                 304.0    2470.0
# YY1_L5_AAVS1_R2                                 313.0    2988.0
# ZNF143_L1_AAVS1_R2                              829.0    4121.0
# ZNF143_L3_AAVS1_R2                              792.0    3235.0
#
# [84200 rows x 17 columns]

# %%
sorted(RASFullCounts.columns)
# Out:
# ['BXPC3_125x-Cas9VY-RAS-RepNA-P4(D21)',
#  'BXPC3_250x-Cas9VY-RAS-RepNA-P4(D21)',
#  'BXPC3_500x-Cas9VY-RAS-RepNA-P4(D21)',
#  'COLO205_250x-Cas9VY-RAS-RepNA-P4(D21)',
#  'COLO678_250x-Cas9VY-RAS-RepNA-P5(D25)',
#  'HCT15_250x-Cas9VY-RAS-RepNA-P4(D21)',
#  'HPAFII_500x-Cas9VY-RAS-RepNA-P4(D21)',
#  'IPC298_250x-Cas9311-RAS-RepNA-P4(D21)',
#  'IPC298_500x-Cas9311-RAS-RepNA-P4(D21)',
#  'PANC0203-Cas9VY-RAS-RepNA-P4(D21)',
#  'PANC1-Cas9VY-RAS-RepNA-P4(D21)',
#  'RAS-pDNA',
#  'SNU1079_250x-Cas9VY-RAS-RepNA-P5(D25)',
#  'SNU410_125x-Cas9VY-RAS-RepNA-P4(D21)',
#  'SNU410_250x-Cas9VY-RAS-RepNA-P4(D21)',
#  'SNU410_500x-Cas9VY-RAS-RepNA-P4(D21)',
#  'SNU478_250x-Cas9VY-RAS-RepNA-P4(D21)']

# %% [markdown]
# # Handling Sequence information

# %%
# RASSequenceMap = tc.get(name='RASscreen05132024-a0fe', version=2, file='RASSequenceMap')
# RASSequenceMap

# %%
RASSequenceMap= pd.read_csv('/home/ubuntu/RAS/ras_screens/analysis/RAS_sequence_map.csv')
RASSequenceMap
# Out:
#                              SequenceName      Cas  Days        Screen  \
# 0     BXPC3_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    BXPC3_250x
# 1     BXPC3_500x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    BXPC3_500x
# 2    HPAFII_500x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   HPAFII_500x
# 3   IPC298_250x-Cas9311-RAS-RepNA-P4(D21)  Cas9311    21   IPC298_250x
# 4   IPC298_500x-Cas9311-RAS-RepNA-P4(D21)  Cas9311    21   IPC298_500x
# 5       PANC0203-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21      PANC0203
# 6          PANC1-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21         PANC1
# 7    SNU410_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU410_250x
# 8    SNU410_500x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU410_500x
# 9   COLO205_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21  COLO205_250x
# 10    HCT15_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    HCT15_250x
# 11   SNU478_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU478_250x
# 12  SNU1079_250x-Cas9VY-RAS-RepNA-P5(D25)   Cas9VY    25  SNU1079_250x
# 13  COLO678_250x-Cas9VY-RAS-RepNA-P5(D25)   Cas9VY    25  COLO678_250x
# 14   SNU410_125x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU410_125x
# 15    BXPC3_125x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    BXPC3_125x
# 16                               RAS-pDNA      NaN     0          pDNA
#
#     CellLine ScreenType Replicates     Treatment   Source
# 0      BXPC3   Parental       RepA          250x  Sellers
# 1      BXPC3   Parental       RepA          500x  Sellers
# 2     HPAFII   Parental       RepA          500x  Sellers
# 3     IPC298   Parental       RepA          250x  Sellers
# 4     IPC298   Parental       RepA          500x  Sellers
# 5   PANC0203   Parental       RepA  No Treatment  Sellers
# 6      PANC1   Parental       RepA  No Treatment  Sellers
# 7     SNU410   Parental       RepA          250x  Sellers
# 8     SNU410   Parental       RepA          500x  Sellers
# 9    COLO205   Parental       RepA          250x  Sellers
# 10     HCT15   Parental       RepA          250x  Sellers
# 11    SNU478   Parental       RepA          250x  Sellers
# 12   SNU1079   Parental       RepA          250x  Sellers
# 13   COLO678   Parental       RepA          250x  Sellers
# 14    SNU410   Parental       RepA          125x  Sellers
# 15     BXPC3   Parental       RepA          125x  Sellers
# 16      pDNA       pDNA       RepA  No Treatment  Sellers

# %%
def check_same_days(group):
    return group['Days'].nunique() == 1

result = RASSequenceMap.groupby('Screen').apply(check_same_days)

# Output the result
print(result[result==False])
# Out:
# Series([], dtype: bool)
# /tmp/ipykernel_10416/3135116447.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result = RASSequenceMap.groupby('Screen').apply(check_same_days)

# %%
def check_days(row):
    if  str(row['SequenceName']) != "nan":
        if "(D" in row['SequenceName']:
            start_idx = row['SequenceName'].find("(D") + 2
            num_str = row['SequenceName'][start_idx:start_idx+2]
            
            if num_str.isdigit():

                return int(num_str) == row['Days']
        return True
    
df = RASSequenceMap.copy()
df['Check'] = df.apply(check_days, axis=1)


print(df.loc[df['Check']==False])
# Out:
# Empty DataFrame
# Columns: [SequenceName, Cas, Days, Screen, CellLine, ScreenType, Replicates, Treatment, Source, Check]
# Index: []

# %%
set(RASSequenceMap['Days'])
# Out:
# {0, 21, 25}

# %%
# Reorder with counts matrix
RASSequenceMap = RASSequenceMap.set_index('SequenceName').loc[RASFullCounts.columns,].rename_axis('SequenceName').reset_index()

# %%
# Add ModelID
Model = tc.get(name='internal-24q4-8c04', file='Model')
ModelCondition = tc.get(name='internal-24q4-8c04', file='ModelCondition')
# Out:
# No dataset version provided. Using version 117.
# No dataset version provided. Using version 117.

# %%
RASSequenceMap.shape
# Out:
# (17, 9)

# %%
Model.columns
# Out:
# Index(['ModelID', 'PatientID', 'CellLineName', 'StrippedCellLineName',
#        'DepmapModelType', 'OncotreeLineage', 'OncotreePrimaryDisease',
#        'OncotreeSubtype', 'OncotreeCode', 'PatientSubtypeFeatures', 'RRID',
#        'Age', 'AgeCategory', 'Sex', 'PatientRace', 'PrimaryOrMetastasis',
#        'SampleCollectionSite', 'SourceType', 'SourceDetail', 'CatalogNumber',
#        'ModelType', 'TissueOrigin', 'ModelDerivationMaterial',
#        'ModelTreatment', 'PatientTreatmentStatus', 'PatientTreatmentType',
#        'PatientTreatmentDetails', 'Stage', 'StagingSystem',
#        'PatientTumorGrade', 'PatientTreatmentResponse', 'GrowthPattern',
#        'OnboardedMedia', 'FormulationID', 'SerumFreeMedia', 'PlateCoating',
#        'EngineeredModel', 'EngineeredModelDetails', 'CulturedResistanceDrug',
#        'PublicComments', 'CCLEName', 'HCMIID', 'ModelAvailableInDbgap',
#        'ModelSubtypeFeatures', 'WTSIMasterCellID', 'SangerModelID',
#        'COSMICID'],
#       dtype='object')

# %%
RASSequenceMap = RASSequenceMap.merge(
    Model[['ModelID', 'PatientID', 'CellLineName', 'StrippedCellLineName', 'CCLEName',
           'DepmapModelType', 'OncotreeLineage', 'OncotreePrimaryDisease',
           'OncotreeSubtype', 'OncotreeCode', 'SangerModelID', 'COSMICID']], 
    left_on='CellLine', right_on='StrippedCellLineName', how ='left')

# %%
RASSequenceMap
# Out:
#                              SequenceName      Cas  Days        Screen  \
# 0   SNU1079_250x-Cas9VY-RAS-RepNA-P5(D25)   Cas9VY    25  SNU1079_250x
# 1   COLO678_250x-Cas9VY-RAS-RepNA-P5(D25)   Cas9VY    25  COLO678_250x
# 2    SNU410_125x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU410_125x
# 3     BXPC3_125x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    BXPC3_125x
# 4    SNU478_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU478_250x
# 5     HCT15_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    HCT15_250x
# 6   COLO205_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21  COLO205_250x
# 7    HPAFII_500x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   HPAFII_500x
# 8     BXPC3_500x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    BXPC3_500x
# 9     BXPC3_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    BXPC3_250x
# 10   SNU410_500x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU410_500x
# 11   SNU410_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU410_250x
# 12  IPC298_500x-Cas9311-RAS-RepNA-P4(D21)  Cas9311    21   IPC298_500x
# 13  IPC298_250x-Cas9311-RAS-RepNA-P4(D21)  Cas9311    21   IPC298_250x
# 14         PANC1-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21         PANC1
# 15      PANC0203-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21      PANC0203
# 16                               RAS-pDNA      NaN     0          pDNA
#
#     CellLine ScreenType Replicates     Treatment   Source     ModelID  ...  \
# 0    SNU1079   Parental       RepA          250x  Sellers  ACH-000209  ...
# 1    COLO678   Parental       RepA          250x  Sellers  ACH-000350  ...
# 2     SNU410   Parental       RepA          125x  Sellers  ACH-000517  ...
# 3      BXPC3   Parental       RepA          125x  Sellers  ACH-000535  ...
# 4     SNU478   Parental       RepA          250x  Sellers  ACH-000377  ...
# 5      HCT15   Parental       RepA          250x  Sellers  ACH-000997  ...
# 6    COLO205   Parental       RepA          250x  Sellers  ACH-001039  ...
# 7     HPAFII   Parental       RepA          500x  Sellers  ACH-000094  ...
# 8      BXPC3   Parental       RepA          500x  Sellers  ACH-000535  ...
# 9      BXPC3   Parental       RepA          250x  Sellers  ACH-000535  ...
# 10    SNU410   Parental       RepA          500x  Sellers  ACH-000517  ...
# 11    SNU410   Parental       RepA          250x  Sellers  ACH-000517  ...
# 12    IPC298   Parental       RepA          500x  Sellers  ACH-000915  ...
# 13    IPC298   Parental       RepA          250x  Sellers  ACH-000915  ...
# 14     PANC1   Parental       RepA  No Treatment  Sellers  ACH-000164  ...
# 15  PANC0203   Parental       RepA  No Treatment  Sellers  ACH-000042  ...
# 16      pDNA       pDNA       RepA  No Treatment  Sellers         NaN  ...
#
#    CellLineName StrippedCellLineName                 CCLEName DepmapModelType  \
# 0      SNU-1079              SNU1079    SNU1079_BILIARY_TRACT            IHCH
# 1      COLO-678              COLO678  COLO678_LARGE_INTESTINE            COAD
# 2       SNU-410               SNU410          SNU410_PANCREAS            PAAD
# 3        BxPC-3                BXPC3           BXPC3_PANCREAS            PAAD
# 4       SNU-478               SNU478     SNU478_BILIARY_TRACT           AMPCA
# 5        HCT-15                HCT15    HCT15_LARGE_INTESTINE            COAD
# 6      COLO 205              COLO205  COLO205_LARGE_INTESTINE            COAD
# 7       HPAF-II               HPAFII          HPAFII_PANCREAS            PAAD
# 8        BxPC-3                BXPC3           BXPC3_PANCREAS            PAAD
# 9        BxPC-3                BXPC3           BXPC3_PANCREAS            PAAD
# 10      SNU-410               SNU410          SNU410_PANCREAS            PAAD
# 11      SNU-410               SNU410          SNU410_PANCREAS            PAAD
# 12      IPC-298               IPC298              IPC298_SKIN            SKCM
# 13      IPC-298               IPC298              IPC298_SKIN            SKCM
# 14       PANC-1                PANC1           PANC1_PANCREAS            PAAD
# 15   Panc 02.03             PANC0203        PANC0203_PANCREAS            PAAD
# 16          NaN                  NaN                      NaN             NaN
#
#      OncotreeLineage                           OncotreePrimaryDisease  \
# 0      Biliary Tract  Intraductal Papillary Neoplasm of the Bile Duct
# 1              Bowel                        Colorectal Adenocarcinoma
# 2           Pancreas                        Pancreatic Adenocarcinoma
# 3           Pancreas                        Pancreatic Adenocarcinoma
# 4   Ampulla of Vater                              Ampullary Carcinoma
# 5              Bowel                        Colorectal Adenocarcinoma
# 6              Bowel                        Colorectal Adenocarcinoma
# 7           Pancreas                        Pancreatic Adenocarcinoma
# 8           Pancreas                        Pancreatic Adenocarcinoma
# 9           Pancreas                        Pancreatic Adenocarcinoma
# 10          Pancreas                        Pancreatic Adenocarcinoma
# 11          Pancreas                        Pancreatic Adenocarcinoma
# 12              Skin                                         Melanoma
# 13              Skin                                         Melanoma
# 14          Pancreas                        Pancreatic Adenocarcinoma
# 15          Pancreas                        Pancreatic Adenocarcinoma
# 16               NaN                                              NaN
#
#                     OncotreeSubtype OncotreeCode SangerModelID   COSMICID
# 0   Intrahepatic Cholangiocarcinoma         IHCH     SIDM00164        NaN
# 1              Colon Adenocarcinoma         COAD     SIDM00957   910689.0
# 2         Pancreatic Adenocarcinoma         PAAD          None        NaN
# 3         Pancreatic Adenocarcinoma         PAAD     SIDM00132   906693.0
# 4               Ampullary Carcinoma        AMPCA     SIDM00160        NaN
# 5              Colon Adenocarcinoma         COAD     SIDM00789   905937.0
# 6              Colon Adenocarcinoma         COAD     SIDM00826   905961.0
# 7         Pancreatic Adenocarcinoma         PAAD     SIDM00669   724869.0
# 8         Pancreatic Adenocarcinoma         PAAD     SIDM00132   906693.0
# 9         Pancreatic Adenocarcinoma         PAAD     SIDM00132   906693.0
# 10        Pancreatic Adenocarcinoma         PAAD          None        NaN
# 11        Pancreatic Adenocarcinoma         PAAD          None        NaN
# 12               Cutaneous Melanoma         SKCM     SIDM01059   907171.0
# 13               Cutaneous Melanoma         SKCM     SIDM01059   907171.0
# 14        Pancreatic Adenocarcinoma         PAAD     SIDM00610        NaN
# 15        Pancreatic Adenocarcinoma         PAAD     SIDM01139  1298475.0
# 16                              NaN          NaN           NaN        NaN
#
# [17 rows x 21 columns]

# %%
# Add data availability
from taigapy import create_taiga_client_v3
from taigapy.client_v3 import UploadedFile, LocalFormat, TaigaReference
tc3 = create_taiga_client_v3()
CRISPRGeneEffect = tc3.get(name='internal-24q4-8c04', file='CRISPRGeneEffect')  # download_to_cache for raw

RASSequenceMap['CRISPR'] = RASSequenceMap['ModelID'].isin(CRISPRGeneEffect.index)
# Out:
# No dataset version provided. Using version 117.

# %%
OmicsCNGene = tc.get(name='internal-24q4-8c04', file='OmicsCNGene')
RASSequenceMap['CopyNumber'] = RASSequenceMap['ModelID'].isin(OmicsCNGene.index)
# Out:
# No dataset version provided. Using version 117.

# %%
OmicsExpressionProteinCodingGenesTPMLogp1 = tc.get(name='internal-24q4-8c04',  file='OmicsExpressionProteinCodingGenesTPMLogp1')
RASSequenceMap['Expression'] = RASSequenceMap['ModelID'].isin(OmicsExpressionProteinCodingGenesTPMLogp1.index)
# Out:
# No dataset version provided. Using version 117.

# %%
OmicsLoH = tc.get(name='internal-24q4-8c04', file='OmicsLoH')
RASSequenceMap['LOH'] = RASSequenceMap['ModelID'].isin(OmicsLoH.index)
RASSequenceMap.loc[~RASSequenceMap['CRISPR']]
# Out:
# No dataset version provided. Using version 117.
#    SequenceName  Cas  Days Screen CellLine ScreenType Replicates  \
# 16     RAS-pDNA  NaN     0   pDNA     pDNA       pDNA       RepA
#
#        Treatment   Source ModelID  ... OncotreeLineage OncotreePrimaryDisease  \
# 16  No Treatment  Sellers     NaN  ...             NaN                    NaN
#
#    OncotreeSubtype OncotreeCode SangerModelID COSMICID CRISPR CopyNumber  \
# 16             NaN          NaN           NaN      NaN  False      False
#
#    Expression    LOH
# 16      False  False
#
# [1 rows x 25 columns]

# %%
RASSequenceMap
# Out:
#                              SequenceName      Cas  Days        Screen  \
# 0   SNU1079_250x-Cas9VY-RAS-RepNA-P5(D25)   Cas9VY    25  SNU1079_250x
# 1   COLO678_250x-Cas9VY-RAS-RepNA-P5(D25)   Cas9VY    25  COLO678_250x
# 2    SNU410_125x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU410_125x
# 3     BXPC3_125x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    BXPC3_125x
# 4    SNU478_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU478_250x
# 5     HCT15_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    HCT15_250x
# 6   COLO205_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21  COLO205_250x
# 7    HPAFII_500x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   HPAFII_500x
# 8     BXPC3_500x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    BXPC3_500x
# 9     BXPC3_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    BXPC3_250x
# 10   SNU410_500x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU410_500x
# 11   SNU410_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU410_250x
# 12  IPC298_500x-Cas9311-RAS-RepNA-P4(D21)  Cas9311    21   IPC298_500x
# 13  IPC298_250x-Cas9311-RAS-RepNA-P4(D21)  Cas9311    21   IPC298_250x
# 14         PANC1-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21         PANC1
# 15      PANC0203-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21      PANC0203
# 16                               RAS-pDNA      NaN     0          pDNA
#
#     CellLine ScreenType Replicates     Treatment   Source     ModelID  ...  \
# 0    SNU1079   Parental       RepA          250x  Sellers  ACH-000209  ...
# 1    COLO678   Parental       RepA          250x  Sellers  ACH-000350  ...
# 2     SNU410   Parental       RepA          125x  Sellers  ACH-000517  ...
# 3      BXPC3   Parental       RepA          125x  Sellers  ACH-000535  ...
# 4     SNU478   Parental       RepA          250x  Sellers  ACH-000377  ...
# 5      HCT15   Parental       RepA          250x  Sellers  ACH-000997  ...
# 6    COLO205   Parental       RepA          250x  Sellers  ACH-001039  ...
# 7     HPAFII   Parental       RepA          500x  Sellers  ACH-000094  ...
# 8      BXPC3   Parental       RepA          500x  Sellers  ACH-000535  ...
# 9      BXPC3   Parental       RepA          250x  Sellers  ACH-000535  ...
# 10    SNU410   Parental       RepA          500x  Sellers  ACH-000517  ...
# 11    SNU410   Parental       RepA          250x  Sellers  ACH-000517  ...
# 12    IPC298   Parental       RepA          500x  Sellers  ACH-000915  ...
# 13    IPC298   Parental       RepA          250x  Sellers  ACH-000915  ...
# 14     PANC1   Parental       RepA  No Treatment  Sellers  ACH-000164  ...
# 15  PANC0203   Parental       RepA  No Treatment  Sellers  ACH-000042  ...
# 16      pDNA       pDNA       RepA  No Treatment  Sellers         NaN  ...
#
#      OncotreeLineage                           OncotreePrimaryDisease  \
# 0      Biliary Tract  Intraductal Papillary Neoplasm of the Bile Duct
# 1              Bowel                        Colorectal Adenocarcinoma
# 2           Pancreas                        Pancreatic Adenocarcinoma
# 3           Pancreas                        Pancreatic Adenocarcinoma
# 4   Ampulla of Vater                              Ampullary Carcinoma
# 5              Bowel                        Colorectal Adenocarcinoma
# 6              Bowel                        Colorectal Adenocarcinoma
# 7           Pancreas                        Pancreatic Adenocarcinoma
# 8           Pancreas                        Pancreatic Adenocarcinoma
# 9           Pancreas                        Pancreatic Adenocarcinoma
# 10          Pancreas                        Pancreatic Adenocarcinoma
# 11          Pancreas                        Pancreatic Adenocarcinoma
# 12              Skin                                         Melanoma
# 13              Skin                                         Melanoma
# 14          Pancreas                        Pancreatic Adenocarcinoma
# 15          Pancreas                        Pancreatic Adenocarcinoma
# 16               NaN                                              NaN
#
#                     OncotreeSubtype OncotreeCode SangerModelID   COSMICID  \
# 0   Intrahepatic Cholangiocarcinoma         IHCH     SIDM00164        NaN
# 1              Colon Adenocarcinoma         COAD     SIDM00957   910689.0
# 2         Pancreatic Adenocarcinoma         PAAD          None        NaN
# 3         Pancreatic Adenocarcinoma         PAAD     SIDM00132   906693.0
# 4               Ampullary Carcinoma        AMPCA     SIDM00160        NaN
# 5              Colon Adenocarcinoma         COAD     SIDM00789   905937.0
# 6              Colon Adenocarcinoma         COAD     SIDM00826   905961.0
# 7         Pancreatic Adenocarcinoma         PAAD     SIDM00669   724869.0
# 8         Pancreatic Adenocarcinoma         PAAD     SIDM00132   906693.0
# 9         Pancreatic Adenocarcinoma         PAAD     SIDM00132   906693.0
# 10        Pancreatic Adenocarcinoma         PAAD          None        NaN
# 11        Pancreatic Adenocarcinoma         PAAD          None        NaN
# 12               Cutaneous Melanoma         SKCM     SIDM01059   907171.0
# 13               Cutaneous Melanoma         SKCM     SIDM01059   907171.0
# 14        Pancreatic Adenocarcinoma         PAAD     SIDM00610        NaN
# 15        Pancreatic Adenocarcinoma         PAAD     SIDM01139  1298475.0
# 16                              NaN          NaN           NaN        NaN
#
#    CRISPR CopyNumber Expression    LOH
# 0    True       True       True   True
# 1    True       True       True   True
# 2    True       True       True  False
# 3    True       True       True   True
# 4    True       True       True   True
# 5    True       True       True   True
# 6    True       True      False   True
# 7    True       True       True   True
# 8    True       True       True   True
# 9    True       True       True   True
# 10   True       True       True  False
# 11   True       True       True  False
# 12   True       True       True   True
# 13   True       True       True   True
# 14   True       True       True   True
# 15   True       True       True  False
# 16  False      False      False  False
#
# [17 rows x 25 columns]

# %%
RASScreenMap=RASSequenceMap.copy(deep=True).iloc[:,1:]

RASScreenMap=RASScreenMap.drop('Replicates',axis=1)
RASScreenMap=RASScreenMap.loc[:,[ 'Screen', 'CellLine', 'ScreenType', 'Treatment',
       'Source', 'Cas', 'Days','ModelID', 'PatientID', 'CellLineName',
       'StrippedCellLineName', 'CCLEName', 'DepmapModelType',
       'OncotreeLineage', 'OncotreePrimaryDisease', 'OncotreeSubtype',
       'OncotreeCode', 'SangerModelID', 'COSMICID', 'CRISPR', 'CopyNumber',
       'Expression', 'LOH']]
RASScreenMap = RASScreenMap.drop_duplicates()
RASScreenMap
# Out:
#           Screen  CellLine ScreenType     Treatment   Source      Cas  Days  \
# 0   SNU1079_250x   SNU1079   Parental          250x  Sellers   Cas9VY    25
# 1   COLO678_250x   COLO678   Parental          250x  Sellers   Cas9VY    25
# 2    SNU410_125x    SNU410   Parental          125x  Sellers   Cas9VY    21
# 3     BXPC3_125x     BXPC3   Parental          125x  Sellers   Cas9VY    21
# 4    SNU478_250x    SNU478   Parental          250x  Sellers   Cas9VY    21
# 5     HCT15_250x     HCT15   Parental          250x  Sellers   Cas9VY    21
# 6   COLO205_250x   COLO205   Parental          250x  Sellers   Cas9VY    21
# 7    HPAFII_500x    HPAFII   Parental          500x  Sellers   Cas9VY    21
# 8     BXPC3_500x     BXPC3   Parental          500x  Sellers   Cas9VY    21
# 9     BXPC3_250x     BXPC3   Parental          250x  Sellers   Cas9VY    21
# 10   SNU410_500x    SNU410   Parental          500x  Sellers   Cas9VY    21
# 11   SNU410_250x    SNU410   Parental          250x  Sellers   Cas9VY    21
# 12   IPC298_500x    IPC298   Parental          500x  Sellers  Cas9311    21
# 13   IPC298_250x    IPC298   Parental          250x  Sellers  Cas9311    21
# 14         PANC1     PANC1   Parental  No Treatment  Sellers   Cas9VY    21
# 15      PANC0203  PANC0203   Parental  No Treatment  Sellers   Cas9VY    21
# 16          pDNA      pDNA       pDNA  No Treatment  Sellers      NaN     0
#
#        ModelID  PatientID CellLineName  ...   OncotreeLineage  \
# 0   ACH-000209  PT-xTQ9GQ     SNU-1079  ...     Biliary Tract
# 1   ACH-000350  PT-j0XD5z     COLO-678  ...             Bowel
# 2   ACH-000517  PT-V7OSXp      SNU-410  ...          Pancreas
# 3   ACH-000535  PT-xfjEoE       BxPC-3  ...          Pancreas
# 4   ACH-000377  PT-gf9GtH      SNU-478  ...  Ampulla of Vater
# 5   ACH-000997  PT-i0VYNQ       HCT-15  ...             Bowel
# 6   ACH-001039  PT-BLAWlD     COLO 205  ...             Bowel
# 7   ACH-000094  PT-bW9aaR      HPAF-II  ...          Pancreas
# 8   ACH-000535  PT-xfjEoE       BxPC-3  ...          Pancreas
# 9   ACH-000535  PT-xfjEoE       BxPC-3  ...          Pancreas
# 10  ACH-000517  PT-V7OSXp      SNU-410  ...          Pancreas
# 11  ACH-000517  PT-V7OSXp      SNU-410  ...          Pancreas
# 12  ACH-000915  PT-Jc7cdo      IPC-298  ...              Skin
# 13  ACH-000915  PT-Jc7cdo      IPC-298  ...              Skin
# 14  ACH-000164  PT-cHU83i       PANC-1  ...          Pancreas
# 15  ACH-000042  PT-QOpMVz   Panc 02.03  ...          Pancreas
# 16         NaN        NaN          NaN  ...               NaN
#
#                              OncotreePrimaryDisease  \
# 0   Intraductal Papillary Neoplasm of the Bile Duct
# 1                         Colorectal Adenocarcinoma
# 2                         Pancreatic Adenocarcinoma
# 3                         Pancreatic Adenocarcinoma
# 4                               Ampullary Carcinoma
# 5                         Colorectal Adenocarcinoma
# 6                         Colorectal Adenocarcinoma
# 7                         Pancreatic Adenocarcinoma
# 8                         Pancreatic Adenocarcinoma
# 9                         Pancreatic Adenocarcinoma
# 10                        Pancreatic Adenocarcinoma
# 11                        Pancreatic Adenocarcinoma
# 12                                         Melanoma
# 13                                         Melanoma
# 14                        Pancreatic Adenocarcinoma
# 15                        Pancreatic Adenocarcinoma
# 16                                              NaN
#
#                     OncotreeSubtype OncotreeCode SangerModelID   COSMICID  \
# 0   Intrahepatic Cholangiocarcinoma         IHCH     SIDM00164        NaN
# 1              Colon Adenocarcinoma         COAD     SIDM00957   910689.0
# 2         Pancreatic Adenocarcinoma         PAAD          None        NaN
# 3         Pancreatic Adenocarcinoma         PAAD     SIDM00132   906693.0
# 4               Ampullary Carcinoma        AMPCA     SIDM00160        NaN
# 5              Colon Adenocarcinoma         COAD     SIDM00789   905937.0
# 6              Colon Adenocarcinoma         COAD     SIDM00826   905961.0
# 7         Pancreatic Adenocarcinoma         PAAD     SIDM00669   724869.0
# 8         Pancreatic Adenocarcinoma         PAAD     SIDM00132   906693.0
# 9         Pancreatic Adenocarcinoma         PAAD     SIDM00132   906693.0
# 10        Pancreatic Adenocarcinoma         PAAD          None        NaN
# 11        Pancreatic Adenocarcinoma         PAAD          None        NaN
# 12               Cutaneous Melanoma         SKCM     SIDM01059   907171.0
# 13               Cutaneous Melanoma         SKCM     SIDM01059   907171.0
# 14        Pancreatic Adenocarcinoma         PAAD     SIDM00610        NaN
# 15        Pancreatic Adenocarcinoma         PAAD     SIDM01139  1298475.0
# 16                              NaN          NaN           NaN        NaN
#
#    CRISPR CopyNumber  Expression    LOH
# 0    True       True        True   True
# 1    True       True        True   True
# 2    True       True        True  False
# 3    True       True        True   True
# 4    True       True        True   True
# 5    True       True        True   True
# 6    True       True       False   True
# 7    True       True        True   True
# 8    True       True        True   True
# 9    True       True        True   True
# 10   True       True        True  False
# 11   True       True        True  False
# 12   True       True        True   True
# 13   True       True        True   True
# 14   True       True        True   True
# 15   True       True        True  False
# 16  False      False       False  False
#
# [17 rows x 23 columns]

# %%
RASFullCounts
# Out:
#                     SNU1079_250x-Cas9VY-RAS-RepNA-P5(D25)  \
# AAVS1_L5_ABCB7_R4                                  5595.0
# AAVS1_L5_ABCB7_R6                                  5136.0
# AAVS1_L5_ABCF1_R2                                  1745.0
# AAVS1_L5_ABCF1_R4                                  1705.0
# AAVS1_L5_ABL1_R2                                   3581.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                  2969.0
# YY1_L1_AAVS1_R2                                    7338.0
# YY1_L5_AAVS1_R2                                     706.0
# ZNF143_L1_AAVS1_R2                                 6936.0
# ZNF143_L3_AAVS1_R2                                 5058.0
#
#                     COLO678_250x-Cas9VY-RAS-RepNA-P5(D25)  \
# AAVS1_L5_ABCB7_R4                                   321.0
# AAVS1_L5_ABCB7_R6                                   515.0
# AAVS1_L5_ABCF1_R2                                   238.0
# AAVS1_L5_ABCF1_R4                                   410.0
# AAVS1_L5_ABL1_R2                                    886.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                  1066.0
# YY1_L1_AAVS1_R2                                     126.0
# YY1_L5_AAVS1_R2                                      54.0
# ZNF143_L1_AAVS1_R2                                 1522.0
# ZNF143_L3_AAVS1_R2                                 1039.0
#
#                     SNU410_125x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                  114.0
# AAVS1_L5_ABCB7_R6                                  111.0
# AAVS1_L5_ABCF1_R2                                   67.0
# AAVS1_L5_ABCF1_R4                                  329.0
# AAVS1_L5_ABL1_R2                                   876.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                  691.0
# YY1_L1_AAVS1_R2                                     91.0
# YY1_L5_AAVS1_R2                                    901.0
# ZNF143_L1_AAVS1_R2                                 426.0
# ZNF143_L3_AAVS1_R2                                 820.0
#
#                     BXPC3_125x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                 663.0
# AAVS1_L5_ABCB7_R6                                 194.0
# AAVS1_L5_ABCF1_R2                                 127.0
# AAVS1_L5_ABCF1_R4                                 251.0
# AAVS1_L5_ABL1_R2                                 1051.0
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                                 436.0
# YY1_L1_AAVS1_R2                                   239.0
# YY1_L5_AAVS1_R2                                   331.0
# ZNF143_L1_AAVS1_R2                                976.0
# ZNF143_L3_AAVS1_R2                               1025.0
#
#                     SNU478_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                    0.0
# AAVS1_L5_ABCB7_R6                                    1.0
# AAVS1_L5_ABCF1_R2                                   70.0
# AAVS1_L5_ABCF1_R4                                  135.0
# AAVS1_L5_ABL1_R2                                   451.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                  525.0
# YY1_L1_AAVS1_R2                                     19.0
# YY1_L5_AAVS1_R2                                    323.0
# ZNF143_L1_AAVS1_R2                                 288.0
# ZNF143_L3_AAVS1_R2                                 595.0
#
#                     HCT15_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                  79.0
# AAVS1_L5_ABCB7_R6                                  34.0
# AAVS1_L5_ABCF1_R2                                  54.0
# AAVS1_L5_ABCF1_R4                                 185.0
# AAVS1_L5_ABL1_R2                                 1256.0
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                                 654.0
# YY1_L1_AAVS1_R2                                   140.0
# YY1_L5_AAVS1_R2                                    80.0
# ZNF143_L1_AAVS1_R2                               1143.0
# ZNF143_L3_AAVS1_R2                                552.0
#
#                     COLO205_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                   177.0
# AAVS1_L5_ABCB7_R6                                   138.0
# AAVS1_L5_ABCF1_R2                                   224.0
# AAVS1_L5_ABCF1_R4                                   145.0
# AAVS1_L5_ABL1_R2                                    591.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                   183.0
# YY1_L1_AAVS1_R2                                     182.0
# YY1_L5_AAVS1_R2                                     110.0
# ZNF143_L1_AAVS1_R2                                  872.0
# ZNF143_L3_AAVS1_R2                                  427.0
#
#                     HPAFII_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                  279.0
# AAVS1_L5_ABCB7_R6                                   21.0
# AAVS1_L5_ABCF1_R2                                   24.0
# AAVS1_L5_ABCF1_R4                                  701.0
# AAVS1_L5_ABL1_R2                                  2694.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                  169.0
# YY1_L1_AAVS1_R2                                    281.0
# YY1_L5_AAVS1_R2                                    117.0
# ZNF143_L1_AAVS1_R2                                 328.0
# ZNF143_L3_AAVS1_R2                                 893.0
#
#                     BXPC3_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                 431.0
# AAVS1_L5_ABCB7_R6                                 428.0
# AAVS1_L5_ABCF1_R2                                 336.0
# AAVS1_L5_ABCF1_R4                                 491.0
# AAVS1_L5_ABL1_R2                                 1185.0
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                                 938.0
# YY1_L1_AAVS1_R2                                   243.0
# YY1_L5_AAVS1_R2                                   532.0
# ZNF143_L1_AAVS1_R2                                888.0
# ZNF143_L3_AAVS1_R2                               1148.0
#
#                     BXPC3_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                 440.0
# AAVS1_L5_ABCB7_R6                                 263.0
# AAVS1_L5_ABCF1_R2                                 221.0
# AAVS1_L5_ABCF1_R4                                 165.0
# AAVS1_L5_ABL1_R2                                  957.0
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                                 429.0
# YY1_L1_AAVS1_R2                                   296.0
# YY1_L5_AAVS1_R2                                   575.0
# ZNF143_L1_AAVS1_R2                               1219.0
# ZNF143_L3_AAVS1_R2                                862.0
#
#                     SNU410_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                  275.0
# AAVS1_L5_ABCB7_R6                                  635.0
# AAVS1_L5_ABCF1_R2                                  746.0
# AAVS1_L5_ABCF1_R4                                  963.0
# AAVS1_L5_ABL1_R2                                  2533.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                 3327.0
# YY1_L1_AAVS1_R2                                    525.0
# YY1_L5_AAVS1_R2                                   1017.0
# ZNF143_L1_AAVS1_R2                                1090.0
# ZNF143_L3_AAVS1_R2                                1667.0
#
#                     SNU410_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                   57.0
# AAVS1_L5_ABCB7_R6                                   30.0
# AAVS1_L5_ABCF1_R2                                  166.0
# AAVS1_L5_ABCF1_R4                                  147.0
# AAVS1_L5_ABL1_R2                                  1396.0
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                                 2696.0
# YY1_L1_AAVS1_R2                                    377.0
# YY1_L5_AAVS1_R2                                    392.0
# ZNF143_L1_AAVS1_R2                                 878.0
# ZNF143_L3_AAVS1_R2                                 712.0
#
#                     IPC298_500x-Cas9311-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                     1.0
# AAVS1_L5_ABCB7_R6                                     0.0
# AAVS1_L5_ABCF1_R2                                    54.0
# AAVS1_L5_ABCF1_R4                                   510.0
# AAVS1_L5_ABL1_R2                                    671.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                    79.0
# YY1_L1_AAVS1_R2                                     124.0
# YY1_L5_AAVS1_R2                                     101.0
# ZNF143_L1_AAVS1_R2                                  129.0
# ZNF143_L3_AAVS1_R2                                  551.0
#
#                     IPC298_250x-Cas9311-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                                     0.0
# AAVS1_L5_ABCB7_R6                                     0.0
# AAVS1_L5_ABCF1_R2                                    13.0
# AAVS1_L5_ABCF1_R4                                    64.0
# AAVS1_L5_ABL1_R2                                    325.0
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                   382.0
# YY1_L1_AAVS1_R2                                      20.0
# YY1_L5_AAVS1_R2                                      65.0
# ZNF143_L1_AAVS1_R2                                  134.0
# ZNF143_L3_AAVS1_R2                                  317.0
#
#                     PANC1-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                            142.0
# AAVS1_L5_ABCB7_R6                            182.0
# AAVS1_L5_ABCF1_R2                            283.0
# AAVS1_L5_ABCF1_R4                            261.0
# AAVS1_L5_ABL1_R2                             402.0
# ...                                            ...
# YWHAZ_L3_YWHAG_R6                            368.0
# YY1_L1_AAVS1_R2                               30.0
# YY1_L5_AAVS1_R2                              117.0
# ZNF143_L1_AAVS1_R2                           489.0
# ZNF143_L3_AAVS1_R2                           310.0
#
#                     PANC0203-Cas9VY-RAS-RepNA-P4(D21)  RAS-pDNA
# AAVS1_L5_ABCB7_R4                               260.0    2799.0
# AAVS1_L5_ABCB7_R6                               468.0    2236.0
# AAVS1_L5_ABCF1_R2                               133.0    2033.0
# AAVS1_L5_ABCF1_R4                               284.0    1951.0
# AAVS1_L5_ABL1_R2                               1542.0    2996.0
# ...                                               ...       ...
# YWHAZ_L3_YWHAG_R6                              1158.0    2988.0
# YY1_L1_AAVS1_R2                                 304.0    2470.0
# YY1_L5_AAVS1_R2                                 313.0    2988.0
# ZNF143_L1_AAVS1_R2                              829.0    4121.0
# ZNF143_L3_AAVS1_R2                              792.0    3235.0
#
# [84200 rows x 17 columns]

# %% [markdown]
# ## Uploading to taiga

# %%
import os
os.makedirs("/home/ubuntu/RAS/ras_screens/analysis/RASScreen02062025",exist_ok=True)
RASSequenceMap.to_csv("/home/ubuntu/RAS/ras_screens/analysis/RASScreen02062025/RASSequenceMap.csv")
chronos.write_hdf5(RASFullCounts, filename="/home/ubuntu/RAS/ras_screens/analysis/RASScreen02062025/RASFullCounts.hdf5")

# %%
RASSequenceMap
# Out:
#                              SequenceName      Cas  Days        Screen  \
# 0   SNU1079_250x-Cas9VY-RAS-RepNA-P5(D25)   Cas9VY    25  SNU1079_250x
# 1   COLO678_250x-Cas9VY-RAS-RepNA-P5(D25)   Cas9VY    25  COLO678_250x
# 2    SNU410_125x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU410_125x
# 3     BXPC3_125x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    BXPC3_125x
# 4    SNU478_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU478_250x
# 5     HCT15_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    HCT15_250x
# 6   COLO205_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21  COLO205_250x
# 7    HPAFII_500x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   HPAFII_500x
# 8     BXPC3_500x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    BXPC3_500x
# 9     BXPC3_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21    BXPC3_250x
# 10   SNU410_500x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU410_500x
# 11   SNU410_250x-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21   SNU410_250x
# 12  IPC298_500x-Cas9311-RAS-RepNA-P4(D21)  Cas9311    21   IPC298_500x
# 13  IPC298_250x-Cas9311-RAS-RepNA-P4(D21)  Cas9311    21   IPC298_250x
# 14         PANC1-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21         PANC1
# 15      PANC0203-Cas9VY-RAS-RepNA-P4(D21)   Cas9VY    21      PANC0203
# 16                               RAS-pDNA      NaN     0          pDNA
#
#     CellLine ScreenType Replicates     Treatment   Source     ModelID  ...  \
# 0    SNU1079   Parental       RepA          250x  Sellers  ACH-000209  ...
# 1    COLO678   Parental       RepA          250x  Sellers  ACH-000350  ...
# 2     SNU410   Parental       RepA          125x  Sellers  ACH-000517  ...
# 3      BXPC3   Parental       RepA          125x  Sellers  ACH-000535  ...
# 4     SNU478   Parental       RepA          250x  Sellers  ACH-000377  ...
# 5      HCT15   Parental       RepA          250x  Sellers  ACH-000997  ...
# 6    COLO205   Parental       RepA          250x  Sellers  ACH-001039  ...
# 7     HPAFII   Parental       RepA          500x  Sellers  ACH-000094  ...
# 8      BXPC3   Parental       RepA          500x  Sellers  ACH-000535  ...
# 9      BXPC3   Parental       RepA          250x  Sellers  ACH-000535  ...
# 10    SNU410   Parental       RepA          500x  Sellers  ACH-000517  ...
# 11    SNU410   Parental       RepA          250x  Sellers  ACH-000517  ...
# 12    IPC298   Parental       RepA          500x  Sellers  ACH-000915  ...
# 13    IPC298   Parental       RepA          250x  Sellers  ACH-000915  ...
# 14     PANC1   Parental       RepA  No Treatment  Sellers  ACH-000164  ...
# 15  PANC0203   Parental       RepA  No Treatment  Sellers  ACH-000042  ...
# 16      pDNA       pDNA       RepA  No Treatment  Sellers         NaN  ...
#
#      OncotreeLineage                           OncotreePrimaryDisease  \
# 0      Biliary Tract  Intraductal Papillary Neoplasm of the Bile Duct
# 1              Bowel                        Colorectal Adenocarcinoma
# 2           Pancreas                        Pancreatic Adenocarcinoma
# 3           Pancreas                        Pancreatic Adenocarcinoma
# 4   Ampulla of Vater                              Ampullary Carcinoma
# 5              Bowel                        Colorectal Adenocarcinoma
# 6              Bowel                        Colorectal Adenocarcinoma
# 7           Pancreas                        Pancreatic Adenocarcinoma
# 8           Pancreas                        Pancreatic Adenocarcinoma
# 9           Pancreas                        Pancreatic Adenocarcinoma
# 10          Pancreas                        Pancreatic Adenocarcinoma
# 11          Pancreas                        Pancreatic Adenocarcinoma
# 12              Skin                                         Melanoma
# 13              Skin                                         Melanoma
# 14          Pancreas                        Pancreatic Adenocarcinoma
# 15          Pancreas                        Pancreatic Adenocarcinoma
# 16               NaN                                              NaN
#
#                     OncotreeSubtype OncotreeCode SangerModelID   COSMICID  \
# 0   Intrahepatic Cholangiocarcinoma         IHCH     SIDM00164        NaN
# 1              Colon Adenocarcinoma         COAD     SIDM00957   910689.0
# 2         Pancreatic Adenocarcinoma         PAAD          None        NaN
# 3         Pancreatic Adenocarcinoma         PAAD     SIDM00132   906693.0
# 4               Ampullary Carcinoma        AMPCA     SIDM00160        NaN
# 5              Colon Adenocarcinoma         COAD     SIDM00789   905937.0
# 6              Colon Adenocarcinoma         COAD     SIDM00826   905961.0
# 7         Pancreatic Adenocarcinoma         PAAD     SIDM00669   724869.0
# 8         Pancreatic Adenocarcinoma         PAAD     SIDM00132   906693.0
# 9         Pancreatic Adenocarcinoma         PAAD     SIDM00132   906693.0
# 10        Pancreatic Adenocarcinoma         PAAD          None        NaN
# 11        Pancreatic Adenocarcinoma         PAAD          None        NaN
# 12               Cutaneous Melanoma         SKCM     SIDM01059   907171.0
# 13               Cutaneous Melanoma         SKCM     SIDM01059   907171.0
# 14        Pancreatic Adenocarcinoma         PAAD     SIDM00610        NaN
# 15        Pancreatic Adenocarcinoma         PAAD     SIDM01139  1298475.0
# 16                              NaN          NaN           NaN        NaN
#
#    CRISPR CopyNumber Expression    LOH
# 0    True       True       True   True
# 1    True       True       True   True
# 2    True       True       True  False
# 3    True       True       True   True
# 4    True       True       True   True
# 5    True       True       True   True
# 6    True       True      False   True
# 7    True       True       True   True
# 8    True       True       True   True
# 9    True       True       True   True
# 10   True       True       True  False
# 11   True       True       True  False
# 12   True       True       True   True
# 13   True       True       True   True
# 14   True       True       True   True
# 15   True       True       True  False
# 16  False      False      False  False
#
# [17 rows x 25 columns]

# %%
RASScreenMap.to_csv("/home/ubuntu/RAS/ras_screens/analysis/RASScreen02062025/RASScreenMap.csv")

# %%
os.chdir("/home/ubuntu/RAS/ras_screens/analysis/RASScreen02062025")

# %%
from taigapy import create_taiga_client_v3
from taigapy.client_v3 import UploadedFile, LocalFormat, TaigaReference
tc = create_taiga_client_v3()
version = tc.update_dataset('rasscreen02062025-6bdb', 
                            "uploading full counts, sequence map, and screen map", 
                            additions=[
    UploadedFile('RASFullCounts', 
                 local_path=os.path.join("RASFullCounts.hdf5"), 
                 format=LocalFormat.HDF5_MATRIX),
    UploadedFile('RASSequenceMap', 
                 local_path=os.path.join("RASSequenceMap.csv"), 
                 format= LocalFormat.CSV_TABLE),
    UploadedFile('RASScreenMap', 
                 local_path=os.path.join("RASScreenMap.csv"), 
                 format= LocalFormat.CSV_TABLE)
    ]
)

# %% [markdown]
# # __Annotating low pDNA guides__

# %%
# RASGuideMap = tc.get(name='RASv2-library-files-d8b3',  file='RASGuideMap')

RASGuideMap = tc.get(name='ras-library-files-35fa',  file='RASGuideMap')
# RASGuideMap = tc.get(name='ras-library-files-35fa', version=10, file='RasGuidesCombinatoryTable')
# Out:
# No dataset version provided. Using version 12.

# %%
RASGuideMap
# Out:
#       symbol1  geneid1  rank1 symbol2  geneid2  rank2                 gRNA1  \
# 0       AAVS1       17      5   ABCB7       22      4  AGAGCCACATTAACCGGCCC
# 1       AAVS1       17      5   ABCB7       22      6  AGAGCCACATTAACCGGCCC
# 2       AAVS1       17      5   ABCF1       23      2  AGAGCCACATTAACCGGCCC
# 3       AAVS1       17      5   ABCF1       23      4  AGAGCCACATTAACCGGCCC
# 4       AAVS1       17      5    ABL1       25      2  AGAGCCACATTAACCGGCCC
# ...       ...      ...    ...     ...      ...    ...                   ...
# 84195   YWHAZ     7534      3   YWHAG     7532      6  TGTGACTGATCGACAATCCC
# 84196     YY1     7528      1   AAVS1       17      2  GTCGGGTCGTCGGTGACCAG
# 84197     YY1     7528      5   AAVS1       17      2  AGATATTGACCATGAGACAG
# 84198  ZNF143     7702      1   AAVS1       17      2  TGTTACGCTGTGCTTGACAG
# 84199  ZNF143     7702      3   AAVS1       17      2  GGAATGACAGAGTTTCCTGG
#
#                       gRNA2    gRNA2_reverse_comp GuideTargetSymbol  \
# 0      TCACAGTTGCAGTCACACGG  CCGTGTGACTGCAACTGTGA             ABCB7
# 1      GCTCGCCAGTCAGGGAATTG  CAATTCCCTGACTGGCGAGC             ABCB7
# 2      GATGGAGTATGAGCGCCAAG  CTTGGCGCTCATACTCCATC             ABCF1
# 3      GAGATACCCGAAAAGGCAGG  CCTGCCTTTTCGGGTATCTC             ABCF1
# 4      GCAAGGTACTCACAGCCCCA  TGGGGCTGTGAGTACCTTGC              ABL1
# ...                     ...                   ...               ...
# 84195  GAATGAGCCACTGTCGAATG  CATTCGACAGTGGCTCATTC       YWHAZ_YWHAG
# 84196  AGGGAGACATCCGTCGGAGA  TCTCCGACGGATGTCTCCCT               YY1
# 84197  AGGGAGACATCCGTCGGAGA  TCTCCGACGGATGTCTCCCT               YY1
# 84198  AGGGAGACATCCGTCGGAGA  TCTCCGACGGATGTCTCCCT            ZNF143
# 84199  AGGGAGACATCCGTCGGAGA  TCTCCGACGGATGTCTCCCT            ZNF143
#
#                GuideLabel GuideTargetLabel
# 0       AAVS1_L5_ABCB7_R4      AAVS1_ABCB7
# 1       AAVS1_L5_ABCB7_R6      AAVS1_ABCB7
# 2       AAVS1_L5_ABCF1_R2      AAVS1_ABCF1
# 3       AAVS1_L5_ABCF1_R4      AAVS1_ABCF1
# 4        AAVS1_L5_ABL1_R2       AAVS1_ABL1
# ...                   ...              ...
# 84195   YWHAZ_L3_YWHAG_R6      YWHAZ_YWHAG
# 84196     YY1_L1_AAVS1_R2        YY1_AAVS1
# 84197     YY1_L5_AAVS1_R2        YY1_AAVS1
# 84198  ZNF143_L1_AAVS1_R2     ZNF143_AAVS1
# 84199  ZNF143_L3_AAVS1_R2     ZNF143_AAVS1
#
# [84200 rows x 12 columns]

# %%
# import numpy as np

# RASGuideMap['GuideTargetSymbol'] = np.where(
#     (RASGuideMap['symbol1'] != "AAVS1") & (RASGuideMap['symbol2'] != "AAVS1"),
#     RASGuideMap['symbol1'] + "_" + RASGuideMap['symbol2'],  # Case 1: Neither is "AAVS1"
#     np.where(
#         RASGuideMap['symbol1'] == "AAVS1",
#         RASGuideMap['symbol2'],  # Case 2: symbol1 is "AAVS1", use symbol2
#         RASGuideMap['symbol1']   # Case 3: symbol2 is "AAVS1", use symbol1
#     )
# )

# %%
# RASGuideMap['GuideLabel'] = RASGuideMap['symbol1'] +  "_L" + RASGuideMap['rank1'].astype(str) +  "_" + RASGuideMap['symbol2'] +  "_R" + RASGuideMap['rank2'].astype(str)
# RASGuideMap['GuideTargetLabel'] = RASGuideMap['symbol1'] +  "_" + RASGuideMap['symbol2']

# %%
# RASGuideMap.to_csv("/home/ubuntu/RAS/ras_screens/analysis/RASGuideMap.csv", index=False)

# %%
# import os
# from taigapy import create_taiga_client_v3
# from taigapy.client_v3 import UploadedFile, LocalFormat, TaigaReference
# tc = create_taiga_client_v3()
# version = tc.update_dataset('ras-library-files-35fa', 
#                             "Corrected guide map", 
#                             additions=[
#     UploadedFile('RASGuideMap', 
#                  local_path="/home/ubuntu/RAS/ras_screens/analysis/RASGuideMap.csv", 
#                  format=LocalFormat.CSV_TABLE)
  
#     ]
# )

# %%
RASFullCounts['RAS-pDNA']
# Out:
# AAVS1_L5_ABCB7_R4     2799.0
# AAVS1_L5_ABCB7_R6     2236.0
# AAVS1_L5_ABCF1_R2     2033.0
# AAVS1_L5_ABCF1_R4     1951.0
# AAVS1_L5_ABL1_R2      2996.0
#                        ...
# YWHAZ_L3_YWHAG_R6     2988.0
# YY1_L1_AAVS1_R2       2470.0
# YY1_L5_AAVS1_R2       2988.0
# ZNF143_L1_AAVS1_R2    4121.0
# ZNF143_L3_AAVS1_R2    3235.0
# Name: RAS-pDNA, Length: 84200, dtype: float64

# %%
RASGuideMap = (RASGuideMap.
    merge(RASFullCounts['RAS-pDNA'], left_on='GuideLabel', right_index=True, how='left')
)
RASGuideMap.loc[RASGuideMap['RAS-pDNA'] < 50, 'DropReasonsRAS'] = 'pDNA<50'

# %%
RASGuideMap
# Out:
#       symbol1  geneid1  rank1 symbol2  geneid2  rank2                 gRNA1  \
# 0       AAVS1       17      5   ABCB7       22      4  AGAGCCACATTAACCGGCCC
# 1       AAVS1       17      5   ABCB7       22      6  AGAGCCACATTAACCGGCCC
# 2       AAVS1       17      5   ABCF1       23      2  AGAGCCACATTAACCGGCCC
# 3       AAVS1       17      5   ABCF1       23      4  AGAGCCACATTAACCGGCCC
# 4       AAVS1       17      5    ABL1       25      2  AGAGCCACATTAACCGGCCC
# ...       ...      ...    ...     ...      ...    ...                   ...
# 84195   YWHAZ     7534      3   YWHAG     7532      6  TGTGACTGATCGACAATCCC
# 84196     YY1     7528      1   AAVS1       17      2  GTCGGGTCGTCGGTGACCAG
# 84197     YY1     7528      5   AAVS1       17      2  AGATATTGACCATGAGACAG
# 84198  ZNF143     7702      1   AAVS1       17      2  TGTTACGCTGTGCTTGACAG
# 84199  ZNF143     7702      3   AAVS1       17      2  GGAATGACAGAGTTTCCTGG
#
#                       gRNA2    gRNA2_reverse_comp GuideTargetSymbol  \
# 0      TCACAGTTGCAGTCACACGG  CCGTGTGACTGCAACTGTGA             ABCB7
# 1      GCTCGCCAGTCAGGGAATTG  CAATTCCCTGACTGGCGAGC             ABCB7
# 2      GATGGAGTATGAGCGCCAAG  CTTGGCGCTCATACTCCATC             ABCF1
# 3      GAGATACCCGAAAAGGCAGG  CCTGCCTTTTCGGGTATCTC             ABCF1
# 4      GCAAGGTACTCACAGCCCCA  TGGGGCTGTGAGTACCTTGC              ABL1
# ...                     ...                   ...               ...
# 84195  GAATGAGCCACTGTCGAATG  CATTCGACAGTGGCTCATTC       YWHAZ_YWHAG
# 84196  AGGGAGACATCCGTCGGAGA  TCTCCGACGGATGTCTCCCT               YY1
# 84197  AGGGAGACATCCGTCGGAGA  TCTCCGACGGATGTCTCCCT               YY1
# 84198  AGGGAGACATCCGTCGGAGA  TCTCCGACGGATGTCTCCCT            ZNF143
# 84199  AGGGAGACATCCGTCGGAGA  TCTCCGACGGATGTCTCCCT            ZNF143
#
#                GuideLabel GuideTargetLabel  RAS-pDNA DropReasonsParalog
# 0       AAVS1_L5_ABCB7_R4      AAVS1_ABCB7    2799.0                NaN
# 1       AAVS1_L5_ABCB7_R6      AAVS1_ABCB7    2236.0                NaN
# 2       AAVS1_L5_ABCF1_R2      AAVS1_ABCF1    2033.0                NaN
# 3       AAVS1_L5_ABCF1_R4      AAVS1_ABCF1    1951.0                NaN
# 4        AAVS1_L5_ABL1_R2       AAVS1_ABL1    2996.0                NaN
# ...                   ...              ...       ...                ...
# 84195   YWHAZ_L3_YWHAG_R6      YWHAZ_YWHAG    2988.0                NaN
# 84196     YY1_L1_AAVS1_R2        YY1_AAVS1    2470.0                NaN
# 84197     YY1_L5_AAVS1_R2        YY1_AAVS1    2988.0                NaN
# 84198  ZNF143_L1_AAVS1_R2     ZNF143_AAVS1    4121.0                NaN
# 84199  ZNF143_L3_AAVS1_R2     ZNF143_AAVS1    3235.0                NaN
#
# [84200 rows x 14 columns]

# %%
len(sorted(set(RASGuideMap['GuideTargetLabel'])))
# Out:
# 21508

# %%
guide_used = RASGuideMap.loc[RASGuideMap['DropReasonsRAS'].isna(), 'GuideTargetLabel']

# %%
guide_used
# Out:
# 0         AAVS1_ABCB7
# 1         AAVS1_ABCB7
# 2         AAVS1_ABCF1
# 3         AAVS1_ABCF1
# 4          AAVS1_ABL1
#              ...
# 84195     YWHAZ_YWHAG
# 84196       YY1_AAVS1
# 84197       YY1_AAVS1
# 84198    ZNF143_AAVS1
# 84199    ZNF143_AAVS1
# Name: GuideTargetLabel, Length: 84197, dtype: object

# %%
raw_readcounts = RASFullCounts.copy()

# %%
# Calculating Norm counts and LFC
norm_readcounts = pd.DataFrame(
                    1e6 * raw_readcounts.values / raw_readcounts.sum(axis=0).values + 1, 
                    index=raw_readcounts.index, columns=raw_readcounts.columns
                )
chronos_sequence_map = RASSequenceMap[['SequenceName', 'Screen', 'Days']].copy()

# %%
np.shape(raw_readcounts.sum(axis=0).values)
# Out:
# (17,)

# %%
chronos_sequence_map = RASSequenceMap[['SequenceName', 'Screen', 'Days']].copy()

# %%
chronos_sequence_map['pDNA_batch'] = 'RAS'

# %%
chronos_sequence_map
# Out:
#                              SequenceName        Screen  Days pDNA_batch
# 0   SNU1079_250x-Cas9VY-RAS-RepNA-P5(D25)  SNU1079_250x    25        RAS
# 1   COLO678_250x-Cas9VY-RAS-RepNA-P5(D25)  COLO678_250x    25        RAS
# 2    SNU410_125x-Cas9VY-RAS-RepNA-P4(D21)   SNU410_125x    21        RAS
# 3     BXPC3_125x-Cas9VY-RAS-RepNA-P4(D21)    BXPC3_125x    21        RAS
# 4    SNU478_250x-Cas9VY-RAS-RepNA-P4(D21)   SNU478_250x    21        RAS
# 5     HCT15_250x-Cas9VY-RAS-RepNA-P4(D21)    HCT15_250x    21        RAS
# 6   COLO205_250x-Cas9VY-RAS-RepNA-P4(D21)  COLO205_250x    21        RAS
# 7    HPAFII_500x-Cas9VY-RAS-RepNA-P4(D21)   HPAFII_500x    21        RAS
# 8     BXPC3_500x-Cas9VY-RAS-RepNA-P4(D21)    BXPC3_500x    21        RAS
# 9     BXPC3_250x-Cas9VY-RAS-RepNA-P4(D21)    BXPC3_250x    21        RAS
# 10   SNU410_500x-Cas9VY-RAS-RepNA-P4(D21)   SNU410_500x    21        RAS
# 11   SNU410_250x-Cas9VY-RAS-RepNA-P4(D21)   SNU410_250x    21        RAS
# 12  IPC298_500x-Cas9311-RAS-RepNA-P4(D21)   IPC298_500x    21        RAS
# 13  IPC298_250x-Cas9311-RAS-RepNA-P4(D21)   IPC298_250x    21        RAS
# 14         PANC1-Cas9VY-RAS-RepNA-P4(D21)         PANC1    21        RAS
# 15      PANC0203-Cas9VY-RAS-RepNA-P4(D21)      PANC0203    21        RAS
# 16                               RAS-pDNA          pDNA     0        RAS

# %%
chronos_sequence_map = chronos_sequence_map.rename(
        columns={
            'SequenceName': 'sequence_ID', 
            'Screen': 'cell_line_name', 
            'Days': 'days'
        }
)

(norm_readcounts.columns == chronos_sequence_map['sequence_ID']).sum()
# Out:
# 17

# %%
chronos_sequence_map
# Out:
#                               sequence_ID cell_line_name  days pDNA_batch
# 0   SNU1079_250x-Cas9VY-RAS-RepNA-P5(D25)   SNU1079_250x    25        RAS
# 1   COLO678_250x-Cas9VY-RAS-RepNA-P5(D25)   COLO678_250x    25        RAS
# 2    SNU410_125x-Cas9VY-RAS-RepNA-P4(D21)    SNU410_125x    21        RAS
# 3     BXPC3_125x-Cas9VY-RAS-RepNA-P4(D21)     BXPC3_125x    21        RAS
# 4    SNU478_250x-Cas9VY-RAS-RepNA-P4(D21)    SNU478_250x    21        RAS
# 5     HCT15_250x-Cas9VY-RAS-RepNA-P4(D21)     HCT15_250x    21        RAS
# 6   COLO205_250x-Cas9VY-RAS-RepNA-P4(D21)   COLO205_250x    21        RAS
# 7    HPAFII_500x-Cas9VY-RAS-RepNA-P4(D21)    HPAFII_500x    21        RAS
# 8     BXPC3_500x-Cas9VY-RAS-RepNA-P4(D21)     BXPC3_500x    21        RAS
# 9     BXPC3_250x-Cas9VY-RAS-RepNA-P4(D21)     BXPC3_250x    21        RAS
# 10   SNU410_500x-Cas9VY-RAS-RepNA-P4(D21)    SNU410_500x    21        RAS
# 11   SNU410_250x-Cas9VY-RAS-RepNA-P4(D21)    SNU410_250x    21        RAS
# 12  IPC298_500x-Cas9311-RAS-RepNA-P4(D21)    IPC298_500x    21        RAS
# 13  IPC298_250x-Cas9311-RAS-RepNA-P4(D21)    IPC298_250x    21        RAS
# 14         PANC1-Cas9VY-RAS-RepNA-P4(D21)          PANC1    21        RAS
# 15      PANC0203-Cas9VY-RAS-RepNA-P4(D21)       PANC0203    21        RAS
# 16                               RAS-pDNA           pDNA     0        RAS

# %%
full_lfc_seq_sgrna = np.log2(
        chronos.calculate_fold_change(
            norm_readcounts.T,
            chronos_sequence_map,
            rpm_normalize=False
        )
).T.reindex(index=norm_readcounts.index)

# %%
full_lfc_seq_sgrna
# Out:
#                     SNU1079_250x-Cas9VY-RAS-RepNA-P5(D25)  \
# AAVS1_L5_ABCB7_R4                                0.320506
# AAVS1_L5_ABCB7_R6                                0.496441
# AAVS1_L5_ABCF1_R2                               -0.724443
# AAVS1_L5_ABCF1_R4                               -0.699099
# AAVS1_L5_ABL1_R2                                -0.351240
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                               -0.584299
# YY1_L1_AAVS1_R2                                  0.847267
# YY1_L5_AAVS1_R2                                 -2.135959
# ZNF143_L1_AAVS1_R2                               0.095897
# ZNF143_L3_AAVS1_R2                              -0.003424
#
#                     COLO678_250x-Cas9VY-RAS-RepNA-P5(D25)  \
# AAVS1_L5_ABCB7_R4                               -1.215063
# AAVS1_L5_ABCB7_R6                               -0.369926
# AAVS1_L5_ABCF1_R2                               -1.128686
# AAVS1_L5_ABCF1_R4                               -0.471743
# AAVS1_L5_ABL1_R2                                -0.060319
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                0.186924
# YY1_L1_AAVS1_R2                                 -1.974867
# YY1_L5_AAVS1_R2                                 -2.800872
# ZNF143_L1_AAVS1_R2                               0.238440
# ZNF143_L3_AAVS1_R2                               0.048295
#
#                     SNU410_125x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                              -1.887259
# AAVS1_L5_ABCB7_R6                              -1.622404
# AAVS1_L5_ABCF1_R2                              -1.923262
# AAVS1_L5_ABCF1_R4                              -0.277124
# AAVS1_L5_ABL1_R2                                0.432999
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                               0.119841
# YY1_L1_AAVS1_R2                                -1.926342
# YY1_L5_AAVS1_R2                                 0.474428
# ZNF143_L1_AAVS1_R2                             -0.932681
# ZNF143_L3_AAVS1_R2                              0.243178
#
#                     BXPC3_125x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                             -0.092759
# AAVS1_L5_ABCB7_R6                             -1.257312
# AAVS1_L5_ABCF1_R2                             -1.549053
# AAVS1_L5_ABCF1_R4                             -0.808366
# AAVS1_L5_ABL1_R2                               0.427382
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                             -0.708058
# YY1_L1_AAVS1_R2                               -1.162057
# YY1_L5_AAVS1_R2                               -1.039493
# ZNF143_L1_AAVS1_R2                            -0.096000
# ZNF143_L3_AAVS1_R2                             0.292613
#
#                     SNU478_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                              -3.381782
# AAVS1_L5_ABCB7_R6                              -3.058258
# AAVS1_L5_ABCF1_R2                              -1.556103
# AAVS1_L5_ABCF1_R4                              -0.844040
# AAVS1_L5_ABL1_R2                                0.083181
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                               0.288461
# YY1_L1_AAVS1_R2                                -2.680997
# YY1_L5_AAVS1_R2                                -0.347029
# ZNF143_L1_AAVS1_R2                             -0.919968
# ZNF143_L3_AAVS1_R2                              0.351822
#
#                     HCT15_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                             -2.385718
# AAVS1_L5_ABCB7_R6                             -2.578195
# AAVS1_L5_ABCF1_R2                             -2.223404
# AAVS1_L5_ABCF1_R4                             -1.184928
# AAVS1_L5_ABL1_R2                               0.600650
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                             -0.260412
# YY1_L1_AAVS1_R2                               -1.753728
# YY1_L5_AAVS1_R2                               -2.462128
# ZNF143_L1_AAVS1_R2                             0.049109
# ZNF143_L3_AAVS1_R2                            -0.581039
#
#                     COLO205_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                               -1.168285
# AAVS1_L5_ABCB7_R6                               -1.152475
# AAVS1_L5_ABCF1_R2                               -0.485253
# AAVS1_L5_ABCF1_R4                               -0.927157
# AAVS1_L5_ABL1_R2                                 0.245901
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                               -1.215913
# YY1_L1_AAVS1_R2                                 -0.974585
# YY1_L5_AAVS1_R2                                 -1.762002
# ZNF143_L1_AAVS1_R2                               0.347280
# ZNF143_L3_AAVS1_R2                              -0.282561
#
#                     HPAFII_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                              -1.097117
# AAVS1_L5_ABCB7_R6                              -2.723202
# AAVS1_L5_ABCF1_R2                              -2.556904
# AAVS1_L5_ABCF1_R4                               0.503536
# AAVS1_L5_ABL1_R2                                1.791978
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                              -1.724956
# YY1_L1_AAVS1_R2                                -0.926840
# YY1_L5_AAVS1_R2                                -2.075527
# ZNF143_L1_AAVS1_R2                             -1.421597
# ZNF143_L3_AAVS1_R2                              0.171741
#
#                     BXPC3_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                             -0.962688
# AAVS1_L5_ABCB7_R6                             -0.681319
# AAVS1_L5_ABCF1_R2                             -0.837522
# AAVS1_L5_ABCF1_R4                             -0.346238
# AAVS1_L5_ABL1_R2                               0.224708
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                             -0.079980
# YY1_L1_AAVS1_R2                               -1.432425
# YY1_L5_AAVS1_R2                               -0.796579
# ZNF143_L1_AAVS1_R2                            -0.578764
# ZNF143_L3_AAVS1_R2                             0.081446
#
#                     BXPC3_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                             -0.746954
# AAVS1_L5_ABCB7_R6                             -1.051416
# AAVS1_L5_ABCF1_R2                             -1.116777
# AAVS1_L5_ABCF1_R4                             -1.357289
# AAVS1_L5_ABL1_R2                               0.153785
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                             -0.863023
# YY1_L1_AAVS1_R2                               -1.047984
# YY1_L5_AAVS1_R2                               -0.501975
# ZNF143_L1_AAVS1_R2                             0.053541
# ZNF143_L3_AAVS1_R2                            -0.085295
#
#                     SNU410_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                              -2.246071
# AAVS1_L5_ABCB7_R6                              -1.179728
# AAVS1_L5_ABCF1_R2                              -0.884972
# AAVS1_L5_ABCF1_R4                              -0.543560
# AAVS1_L5_ABL1_R2                                0.117539
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                               0.485510
# YY1_L1_AAVS1_R2                                -1.503502
# YY1_L5_AAVS1_R2                                -1.026923
# ZNF143_L1_AAVS1_R2                             -1.372325
# ZNF143_L3_AAVS1_R2                             -0.526133
#
#                     SNU410_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                              -2.768708
# AAVS1_L5_ABCB7_R6                              -2.737557
# AAVS1_L5_ABCF1_R2                              -1.625692
# AAVS1_L5_ABCF1_R4                              -1.677822
# AAVS1_L5_ABL1_R2                                0.333323
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                               1.235671
# YY1_L1_AAVS1_R2                                -1.049061
# YY1_L5_AAVS1_R2                                -1.252655
# ZNF143_L1_AAVS1_R2                             -0.699990
# ZNF143_L3_AAVS1_R2                             -0.643152
#
#                     IPC298_500x-Cas9311-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                               -3.345454
# AAVS1_L5_ABCB7_R6                               -3.092226
# AAVS1_L5_ABCF1_R2                               -1.722554
# AAVS1_L5_ABCF1_R4                                0.887870
# AAVS1_L5_ABL1_R2                                 0.707999
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                               -1.875335
# YY1_L1_AAVS1_R2                                 -1.162405
# YY1_L5_AAVS1_R2                                 -1.629107
# ZNF143_L1_AAVS1_R2                              -1.793939
# ZNF143_L3_AAVS1_R2                               0.339901
#
#                     IPC298_250x-Cas9311-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                               -3.381782
# AAVS1_L5_ABCB7_R6                               -3.092226
# AAVS1_L5_ABCF1_R2                               -2.187412
# AAVS1_L5_ABCF1_R4                               -0.732345
# AAVS1_L5_ABL1_R2                                 0.781422
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                1.006723
# YY1_L1_AAVS1_R2                                 -2.141664
# YY1_L5_AAVS1_R2                                 -1.262105
# ZNF143_L1_AAVS1_R2                              -0.816708
# ZNF143_L3_AAVS1_R2                               0.646292
#
#                     PANC1-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                        -1.217206
# AAVS1_L5_ABCB7_R6                        -0.642117
# AAVS1_L5_ABCF1_R2                         0.017822
# AAVS1_L5_ABCF1_R4                        -0.032012
# AAVS1_L5_ABL1_R2                         -0.029653
# ...                                            ...
# YWHAZ_L3_YWHAG_R6                        -0.141413
# YY1_L1_AAVS1_R2                          -2.424001
# YY1_L5_AAVS1_R2                          -1.514905
# ZNF143_L1_AAVS1_R2                       -0.194830
# ZNF143_L3_AAVS1_R2                       -0.466771
#
#                     PANC0203-Cas9VY-RAS-RepNA-P4(D21)
# AAVS1_L5_ABCB7_R4                           -1.298764
# AAVS1_L5_ABCB7_R6                           -0.321086
# AAVS1_L5_ABCF1_R2                           -1.562556
# AAVS1_L5_ABCF1_R4                           -0.738690
# AAVS1_L5_ABL1_R2                             0.865324
# ...                                               ...
# YWHAZ_L3_YWHAG_R6                            0.479160
# YY1_L1_AAVS1_R2                             -0.961267
# YY1_L5_AAVS1_R2                             -1.175441
# ZNF143_L1_AAVS1_R2                          -0.393861
# ZNF143_L3_AAVS1_R2                          -0.130885
#
# [84200 rows x 16 columns]

# %%
chronos_sequence_map
# Out:
#                               sequence_ID cell_line_name  days pDNA_batch
# 0   SNU1079_250x-Cas9VY-RAS-RepNA-P5(D25)   SNU1079_250x    25        RAS
# 1   COLO678_250x-Cas9VY-RAS-RepNA-P5(D25)   COLO678_250x    25        RAS
# 2    SNU410_125x-Cas9VY-RAS-RepNA-P4(D21)    SNU410_125x    21        RAS
# 3     BXPC3_125x-Cas9VY-RAS-RepNA-P4(D21)     BXPC3_125x    21        RAS
# 4    SNU478_250x-Cas9VY-RAS-RepNA-P4(D21)    SNU478_250x    21        RAS
# 5     HCT15_250x-Cas9VY-RAS-RepNA-P4(D21)     HCT15_250x    21        RAS
# 6   COLO205_250x-Cas9VY-RAS-RepNA-P4(D21)   COLO205_250x    21        RAS
# 7    HPAFII_500x-Cas9VY-RAS-RepNA-P4(D21)    HPAFII_500x    21        RAS
# 8     BXPC3_500x-Cas9VY-RAS-RepNA-P4(D21)     BXPC3_500x    21        RAS
# 9     BXPC3_250x-Cas9VY-RAS-RepNA-P4(D21)     BXPC3_250x    21        RAS
# 10   SNU410_500x-Cas9VY-RAS-RepNA-P4(D21)    SNU410_500x    21        RAS
# 11   SNU410_250x-Cas9VY-RAS-RepNA-P4(D21)    SNU410_250x    21        RAS
# 12  IPC298_500x-Cas9311-RAS-RepNA-P4(D21)    IPC298_500x    21        RAS
# 13  IPC298_250x-Cas9311-RAS-RepNA-P4(D21)    IPC298_250x    21        RAS
# 14         PANC1-Cas9VY-RAS-RepNA-P4(D21)          PANC1    21        RAS
# 15      PANC0203-Cas9VY-RAS-RepNA-P4(D21)       PANC0203    21        RAS
# 16                               RAS-pDNA           pDNA     0        RAS

# %% [markdown]
# # Screen level logFC

# %%
raw_counts_screen = raw_readcounts.T.merge(chronos_sequence_map[['sequence_ID', 'cell_line_name']].set_index('sequence_ID'), how = 'left', left_index=True, right_index=True ).groupby('cell_line_name').sum().T
#chronos_sequence_map['S']

# %%
raw_counts_screen
# Out:
# cell_line_name      BXPC3_125x  BXPC3_250x  BXPC3_500x  COLO205_250x  \
# AAVS1_L5_ABCB7_R4        663.0       440.0       431.0         177.0
# AAVS1_L5_ABCB7_R6        194.0       263.0       428.0         138.0
# AAVS1_L5_ABCF1_R2        127.0       221.0       336.0         224.0
# AAVS1_L5_ABCF1_R4        251.0       165.0       491.0         145.0
# AAVS1_L5_ABL1_R2        1051.0       957.0      1185.0         591.0
# ...                        ...         ...         ...           ...
# YWHAZ_L3_YWHAG_R6        436.0       429.0       938.0         183.0
# YY1_L1_AAVS1_R2          239.0       296.0       243.0         182.0
# YY1_L5_AAVS1_R2          331.0       575.0       532.0         110.0
# ZNF143_L1_AAVS1_R2       976.0      1219.0       888.0         872.0
# ZNF143_L3_AAVS1_R2      1025.0       862.0      1148.0         427.0
#
# cell_line_name      COLO678_250x  HCT15_250x  HPAFII_500x  IPC298_250x  \
# AAVS1_L5_ABCB7_R4          321.0        79.0        279.0          0.0
# AAVS1_L5_ABCB7_R6          515.0        34.0         21.0          0.0
# AAVS1_L5_ABCF1_R2          238.0        54.0         24.0         13.0
# AAVS1_L5_ABCF1_R4          410.0       185.0        701.0         64.0
# AAVS1_L5_ABL1_R2           886.0      1256.0       2694.0        325.0
# ...                          ...         ...          ...          ...
# YWHAZ_L3_YWHAG_R6         1066.0       654.0        169.0        382.0
# YY1_L1_AAVS1_R2            126.0       140.0        281.0         20.0
# YY1_L5_AAVS1_R2             54.0        80.0        117.0         65.0
# ZNF143_L1_AAVS1_R2        1522.0      1143.0        328.0        134.0
# ZNF143_L3_AAVS1_R2        1039.0       552.0        893.0        317.0
#
# cell_line_name      IPC298_500x  PANC0203  PANC1  SNU1079_250x  SNU410_125x  \
# AAVS1_L5_ABCB7_R4           1.0     260.0  142.0        5595.0        114.0
# AAVS1_L5_ABCB7_R6           0.0     468.0  182.0        5136.0        111.0
# AAVS1_L5_ABCF1_R2          54.0     133.0  283.0        1745.0         67.0
# AAVS1_L5_ABCF1_R4         510.0     284.0  261.0        1705.0        329.0
# AAVS1_L5_ABL1_R2          671.0    1542.0  402.0        3581.0        876.0
# ...                         ...       ...    ...           ...          ...
# YWHAZ_L3_YWHAG_R6          79.0    1158.0  368.0        2969.0        691.0
# YY1_L1_AAVS1_R2           124.0     304.0   30.0        7338.0         91.0
# YY1_L5_AAVS1_R2           101.0     313.0  117.0         706.0        901.0
# ZNF143_L1_AAVS1_R2        129.0     829.0  489.0        6936.0        426.0
# ZNF143_L3_AAVS1_R2        551.0     792.0  310.0        5058.0        820.0
#
# cell_line_name      SNU410_250x  SNU410_500x  SNU478_250x    pDNA
# AAVS1_L5_ABCB7_R4          57.0        275.0          0.0  2799.0
# AAVS1_L5_ABCB7_R6          30.0        635.0          1.0  2236.0
# AAVS1_L5_ABCF1_R2         166.0        746.0         70.0  2033.0
# AAVS1_L5_ABCF1_R4         147.0        963.0        135.0  1951.0
# AAVS1_L5_ABL1_R2         1396.0       2533.0        451.0  2996.0
# ...                         ...          ...          ...     ...
# YWHAZ_L3_YWHAG_R6        2696.0       3327.0        525.0  2988.0
# YY1_L1_AAVS1_R2           377.0        525.0         19.0  2470.0
# YY1_L5_AAVS1_R2           392.0       1017.0        323.0  2988.0
# ZNF143_L1_AAVS1_R2        878.0       1090.0        288.0  4121.0
# ZNF143_L3_AAVS1_R2        712.0       1667.0        595.0  3235.0
#
# [84200 rows x 17 columns]

# %%
norm_readcounts_screen = pd.DataFrame(
                    1e6 * raw_counts_screen .values / raw_counts_screen .sum(axis=0).values + 1, 
                    index=raw_counts_screen .index, columns=raw_counts_screen .columns
                )

# %%
norm_readcounts_screen
# Out:
# cell_line_name      BXPC3_125x  BXPC3_250x  BXPC3_500x  COLO205_250x  \
# AAVS1_L5_ABCB7_R4     9.774505    6.211014    5.348354      4.637984
# AAVS1_L5_ABCB7_R6     3.567502    4.114765    5.318087      3.836394
# AAVS1_L5_ABCF1_R2     2.680788    3.617350    4.389900      5.604002
# AAVS1_L5_ABCF1_R4     4.321872    2.954130    5.953693      3.980269
# AAVS1_L5_ABL1_R2     14.909510   12.333955   12.955450     13.147165
# ...                        ...         ...         ...           ...
# YWHAZ_L3_YWHAG_R6     6.770263    6.080738   10.463470      4.761305
# YY1_L1_AAVS1_R2       4.163057    4.505591    3.451624      4.740751
# YY1_L5_AAVS1_R2       5.380635    7.809848    6.367341      3.260894
# ZNF143_L1_AAVS1_R2   13.916919   15.436877    9.959021     18.922721
# ZNF143_L3_AAVS1_R2   14.565412   11.208850   12.582158      9.776378
#
# cell_line_name      COLO678_250x  HCT15_250x  HPAFII_500x  IPC298_250x  \
# AAVS1_L5_ABCB7_R4       4.490013    1.994551     4.872509     1.000000
# AAVS1_L5_ABCB7_R6       6.599243    1.428035     1.291479     1.000000
# AAVS1_L5_ABCF1_R2       3.587611    1.679820     1.333119     1.722254
# AAVS1_L5_ABCF1_R4       5.457650    3.329012    10.729853     4.555714
# AAVS1_L5_ABL1_R2       10.632872   16.812104    38.392617    19.056361
# ...                          ...         ...          ...          ...
# YWHAZ_L3_YWHAG_R6      12.589889    9.233373     3.345714    22.223169
# YY1_L1_AAVS1_R2         2.369912    2.762496     4.900269     2.111161
# YY1_L5_AAVS1_R2         1.587105    2.007140     2.623956     4.611272
# ZNF143_L1_AAVS1_R2     17.547665   15.389519     5.552627     8.444777
# ZNF143_L3_AAVS1_R2     12.296336    7.949269    13.394806    18.611897
#
# cell_line_name      IPC298_500x   PANC0203      PANC1  SNU1079_250x  \
# AAVS1_L5_ABCB7_R4      1.025500   4.236928   4.483348     13.016671
# AAVS1_L5_ABCB7_R6      1.000000   6.826471   5.464573     12.030853
# AAVS1_L5_ABCF1_R2      2.377023   2.655813   7.942165      4.747827
# AAVS1_L5_ABCF1_R4     14.005219   4.535722   7.402492      4.661917
# AAVS1_L5_ABL1_R2      18.110789  20.197474  10.861309      8.691099
# ...                         ...        ...        ...           ...
# YWHAZ_L3_YWHAG_R6      3.014534  15.416780  10.027268      7.376675
# YY1_L1_AAVS1_R2        4.162053   4.784716   1.735919     16.760203
# YY1_L5_AAVS1_R2        3.575543   4.896764   3.870083      2.516313
# ZNF143_L1_AAVS1_R2     4.289555  11.320821  12.995473     15.896806
# ZNF143_L3_AAVS1_R2    15.050737  10.860181   8.604492     11.863329
#
# cell_line_name      SNU410_125x  SNU410_250x  SNU410_500x  SNU478_250x  \
# AAVS1_L5_ABCB7_R4      2.817711     1.529515     2.197270     1.000000
# AAVS1_L5_ABCB7_R6      2.769877     1.278692     3.764604     1.023825
# AAVS1_L5_ABCF1_R2      2.068304     2.542095     4.247866     2.667719
# AAVS1_L5_ABCF1_R4      6.245851     2.365590     5.192620     4.216316
# AAVS1_L5_ABL1_R2      14.967677    13.968465    12.027941    11.744876
# ...                         ...          ...          ...          ...
# YWHAZ_L3_YWHAG_R6     12.017882    26.045115    15.484785    13.507894
# YY1_L1_AAVS1_R2        2.450980     4.502229     3.285696     1.452667
# YY1_L5_AAVS1_R2       15.366298     4.641575     5.427721     8.695333
# ZNF143_L1_AAVS1_R2     7.792500     9.156384     5.745541     7.861473
# ZNF143_L3_AAVS1_R2    14.074766     7.614289     8.257631    15.175613
#
# cell_line_name           pDNA
# AAVS1_L5_ABCB7_R4   10.423605
# AAVS1_L5_ABCB7_R6    8.528110
# AAVS1_L5_ABCF1_R2    7.844655
# AAVS1_L5_ABCF1_R4    7.568579
# AAVS1_L5_ABL1_R2    11.086860
# ...                       ...
# YWHAZ_L3_YWHAG_R6   11.059926
# YY1_L1_AAVS1_R2      9.315936
# YY1_L5_AAVS1_R2     11.059926
# ZNF143_L1_AAVS1_R2  14.874483
# ZNF143_L3_AAVS1_R2  11.891519
#
# [84200 rows x 17 columns]

# %%
norm_readcounts_screen
screen_map = pd.DataFrame({'sequence_ID': norm_readcounts_screen.columns, 
                           'cell_line_name': norm_readcounts_screen.columns, 'pDNA_batch': chronos_sequence_map["pDNA_batch"], 'days' : chronos_sequence_map["days"]})
# screen_map = chronos_sequence_map.copy()
full_lfc_screen_sgrna = np.log2(
        chronos.calculate_fold_change(
            norm_readcounts_screen.T,
            screen_map,
            rpm_normalize=False
        )
).T.reindex(index=norm_readcounts_screen.index)

# %%
screen_map
# Out:
#      sequence_ID cell_line_name pDNA_batch  days
# 0     BXPC3_125x     BXPC3_125x        RAS    25
# 1     BXPC3_250x     BXPC3_250x        RAS    25
# 2     BXPC3_500x     BXPC3_500x        RAS    21
# 3   COLO205_250x   COLO205_250x        RAS    21
# 4   COLO678_250x   COLO678_250x        RAS    21
# 5     HCT15_250x     HCT15_250x        RAS    21
# 6    HPAFII_500x    HPAFII_500x        RAS    21
# 7    IPC298_250x    IPC298_250x        RAS    21
# 8    IPC298_500x    IPC298_500x        RAS    21
# 9       PANC0203       PANC0203        RAS    21
# 10         PANC1          PANC1        RAS    21
# 11  SNU1079_250x   SNU1079_250x        RAS    21
# 12   SNU410_125x    SNU410_125x        RAS    21
# 13   SNU410_250x    SNU410_250x        RAS    21
# 14   SNU410_500x    SNU410_500x        RAS    21
# 15   SNU478_250x    SNU478_250x        RAS    21
# 16          pDNA           pDNA        RAS     0

# %%
full_lfc_screen_sgrna
# Out:
# cell_line_name      BXPC3_125x  BXPC3_250x  BXPC3_500x  COLO205_250x  \
# AAVS1_L5_ABCB7_R4    -0.092759   -0.746954   -0.962688     -1.168285
# AAVS1_L5_ABCB7_R6    -1.257312   -1.051416   -0.681319     -1.152475
# AAVS1_L5_ABCF1_R2    -1.549053   -1.116777   -0.837522     -0.485253
# AAVS1_L5_ABCF1_R4    -0.808366   -1.357289   -0.346238     -0.927157
# AAVS1_L5_ABL1_R2      0.427382    0.153785    0.224708      0.245901
# ...                        ...         ...         ...           ...
# YWHAZ_L3_YWHAG_R6    -0.708058   -0.863023   -0.079980     -1.215913
# YY1_L1_AAVS1_R2      -1.162057   -1.047984   -1.432425     -0.974585
# YY1_L5_AAVS1_R2      -1.039493   -0.501975   -0.796579     -1.762002
# ZNF143_L1_AAVS1_R2   -0.096000    0.053541   -0.578764      0.347280
# ZNF143_L3_AAVS1_R2    0.292613   -0.085295    0.081446     -0.282561
#
# cell_line_name      COLO678_250x  HCT15_250x  HPAFII_500x  IPC298_250x  \
# AAVS1_L5_ABCB7_R4      -1.215063   -2.385718    -1.097117    -3.381782
# AAVS1_L5_ABCB7_R6      -0.369926   -2.578195    -2.723202    -3.092226
# AAVS1_L5_ABCF1_R2      -1.128686   -2.223404    -2.556904    -2.187412
# AAVS1_L5_ABCF1_R4      -0.471743   -1.184928     0.503536    -0.732345
# AAVS1_L5_ABL1_R2       -0.060319    0.600650     1.791978     0.781422
# ...                          ...         ...          ...          ...
# YWHAZ_L3_YWHAG_R6       0.186924   -0.260412    -1.724956     1.006723
# YY1_L1_AAVS1_R2        -1.974867   -1.753728    -0.926840    -2.141664
# YY1_L5_AAVS1_R2        -2.800872   -2.462128    -2.075527    -1.262105
# ZNF143_L1_AAVS1_R2      0.238440    0.049109    -1.421597    -0.816708
# ZNF143_L3_AAVS1_R2      0.048295   -0.581039     0.171741     0.646292
#
# cell_line_name      IPC298_500x  PANC0203     PANC1  SNU1079_250x  \
# AAVS1_L5_ABCB7_R4     -3.345454 -1.298764 -1.217206      0.320506
# AAVS1_L5_ABCB7_R6     -3.092226 -0.321086 -0.642117      0.496441
# AAVS1_L5_ABCF1_R2     -1.722554 -1.562556  0.017822     -0.724443
# AAVS1_L5_ABCF1_R4      0.887870 -0.738690 -0.032012     -0.699099
# AAVS1_L5_ABL1_R2       0.707999  0.865324 -0.029653     -0.351240
# ...                         ...       ...       ...           ...
# YWHAZ_L3_YWHAG_R6     -1.875335  0.479160 -0.141413     -0.584299
# YY1_L1_AAVS1_R2       -1.162405 -0.961267 -2.424001      0.847267
# YY1_L5_AAVS1_R2       -1.629107 -1.175441 -1.514905     -2.135959
# ZNF143_L1_AAVS1_R2    -1.793939 -0.393861 -0.194830      0.095897
# ZNF143_L3_AAVS1_R2     0.339901 -0.130885 -0.466771     -0.003424
#
# cell_line_name      SNU410_125x  SNU410_250x  SNU410_500x  SNU478_250x
# AAVS1_L5_ABCB7_R4     -1.887259    -2.768708    -2.246071    -3.381782
# AAVS1_L5_ABCB7_R6     -1.622404    -2.737557    -1.179728    -3.058258
# AAVS1_L5_ABCF1_R2     -1.923262    -1.625692    -0.884972    -1.556103
# AAVS1_L5_ABCF1_R4     -0.277124    -1.677822    -0.543560    -0.844040
# AAVS1_L5_ABL1_R2       0.432999     0.333323     0.117539     0.083181
# ...                         ...          ...          ...          ...
# YWHAZ_L3_YWHAG_R6      0.119841     1.235671     0.485510     0.288461
# YY1_L1_AAVS1_R2       -1.926342    -1.049061    -1.503502    -2.680997
# YY1_L5_AAVS1_R2        0.474428    -1.252655    -1.026923    -0.347029
# ZNF143_L1_AAVS1_R2    -0.932681    -0.699990    -1.372325    -0.919968
# ZNF143_L3_AAVS1_R2     0.243178    -0.643152    -0.526133     0.351822
#
# [84200 rows x 16 columns]

# %%
chronos.write_hdf5(full_lfc_screen_sgrna, "RASFullLfcSgrnaScreen.hdf5")

# %%
import os
from taigapy import create_taiga_client_v3
from taigapy.client_v3 import UploadedFile, LocalFormat, TaigaReference
tc = create_taiga_client_v3()
version = tc.update_dataset('rasscreen02062025-6bdb', 
                            "Uploading Full LFC matrix for screens", 
                            additions=[
    UploadedFile('RASFullLfcSgrnaScreen', 
                 local_path=os.path.join("RASFullLfcSgrnaScreen.hdf5"), 
                 format=LocalFormat.HDF5_MATRIX)
  
    ]
)
# Out:
# Created temporary upload session 447406a3027d4671a55c7c0481440be8
# Uploading RASFullLfcSgrnaScreen.hdf5 to S3
# Finished uploading RASFullLfcSgrnaScreen.hdf5 to S3
# Completed uploading RASFullLfcSgrnaScreen.hdf5 to S3
# Added RASFullLfcSgrnaScreen.hdf5 to upload session 447406a3027d4671a55c7c0481440be8
# Dataset created. Access it directly with this url: https://cds.team/taiga/dataset/rasscreen02062025-6bdb/4

# %% [markdown]
# # Agreement model

# %%
avana_lfc = tc.get(name='internal-24q4-8c04', file='AvanaLogfoldChange') 
avana_guide_map = tc.get(name='internal-24q4-8c04', file='AvanaGuideMap')
screen_seq_map =  tc.get(name='internal-24q4-8c04',file='ScreenSequenceMap').set_index('SequenceID')
avana_replicate_map = screen_seq_map.loc[avana_lfc.columns]
# collapse replicates to cell lines by median
avana_lfc_cell = avana_lfc.groupby(avana_replicate_map.ModelID, axis=1).median()
# Out:
# No dataset version provided. Using version 117.
# No dataset version provided. Using version 117.
# No dataset version provided. Using version 117.
# /tmp/ipykernel_10416/3279475260.py:6: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   avana_lfc_cell = avana_lfc.groupby(avana_replicate_map.ModelID, axis=1).median()

# %%
#copied from DepMap portal code
from scipy.stats import spearmanr, pearsonr
from sklearn.ensemble import RandomForestClassifier
def get_metrics(A, B):
    '''
    computes a bunch of agreement measures between vectors A and B, suitable for seeing
    whether two measurements of gene effect are in agreement
    '''
    assert all(A.index == B.index), "misaligned indices between the two series"
    mask = A.notnull() & B.notnull()
    a = A[mask]
    b = B[mask]
    a = a.loc[b.index]
    meanA = a.mean()
    meanB = b.mean()
    mean_se = (meanA - meanB)**2
    mean_mean = .5*(meanA + meanB)
    corr = a.corr(b)
    spearman = spearmanr(a, b)[0]
    varA = a.var()
    varB = b.var()
    var_se = np.abs(varA - varB)
    var_mean = .5*(varA + varB)
    centered_SE = ((a - meanA - b + meanB) **2).mean()
    status_agreement = ((a < -.5) == (b < -.5)).mean()
    return {
        'mean_se': mean_se,
        'mean_mean': mean_mean,
        'corr': corr,
        'spearman': spearman,
        'var_se': var_se,
        'var_mean': var_mean,
        'centered_SE': centered_SE,
        'max_mean': max(meanA, meanB),
        'min_mean': min(meanA, meanB),
        'max_var': max(varA, varB),
        'min_var': min(varA, varB),
        'max_max': max(max(a), max(b)),
        'min_min': min(min(a), min(b)),
        'status_agreement': status_agreement
    }

# %%
# generate the agreement metrics for 5000 random pairs of guides targeting the same gene
features = []
is_same = pd.Series(dtype='int64')
nsamples = 5000
genes = np.random.choice(avana_guide_map.Gene.dropna().unique(), size=nsamples, replace=False)
for i, gene in enumerate(genes):
    if not i%1000:
        print('%1.0f%% done' % (i * 100./len(genes)))
    guides = avana_guide_map.query('Gene == "%s"' % gene).sgRNA.tolist()
    if len(guides) < 2:
        continue     
    np.random.shuffle(guides)
    
    out = get_metrics(avana_lfc_cell.loc[guides[0]], avana_lfc_cell.loc[guides[1]])
    out.update({'gene': gene, 'guide1': guides[0], 'guide2': guides[1]})
    features.append(out)
    is_same[gene] = 1
    
# then generate the agreement metrics for 5000 random pairs of guides targeting different genes 
# (using same individual genes as above)
for i, gene in enumerate(genes):
    if not i%1000:
        print('%1.0f%% done' % (i * 100./len(genes)))
    guides = avana_guide_map.query('Gene == "%s"' % gene).sgRNA.tolist()
    if len(guides) < 2:
        continue
        
    gene2 = gene
    while gene2 == gene or (gene + ' x ' + gene2) in is_same:
        gene2 = np.random.choice(genes)
        guide2 = np.random.choice(avana_guide_map.query('Gene == %r' % gene2).sgRNA)

    guide1 = guides[0]
    # avoid the (unlikely) case that the two genes happen to share a guide and 
    # we've chosen that guide for both genes
    while guide1 == guide2:
        guide1 = np.random.choice(guides)
    np.random.shuffle(guides)
    # a human readable name for the pair of chosen genes
    pseudogene = gene + ' x ' + gene2
    
    out = get_metrics(avana_lfc_cell.loc[guide1], avana_lfc_cell.loc[guide2])
    out.update({'gene': pseudogene, 'guide1': guide1, 'guide2': guide2})
    features.append(out)
    is_same[pseudogene] = 0
    
features = pd.DataFrame(features).set_index('gene')

model = RandomForestClassifier(20, min_impurity_decrease=.00001, min_samples_leaf=100, max_depth=6)
model.fit(features.drop(['guide1','guide2'], axis=1).values, is_same.values)
# Out:
# 0% done
# 20% done
# 40% done
# 60% done
# 80% done
# 0% done
# 20% done
# 40% done
# 60% done
# 80% done
# RandomForestClassifier(max_depth=6, min_impurity_decrease=1e-05,
#                        min_samples_leaf=100, n_estimators=20)

# %%
import seaborn as sns
from matplotlib import pyplot as plt
# Compute in sample separation (training data)
in_sample = model.predict_proba(
    features.drop(['guide1', 'guide2'], axis=1).values, 
)[:, 1]
f, ax = plt.subplots(1, 1, figsize=(3.5,2.5))
sns.kdeplot(in_sample[is_same==1], label="Same Gene", ax=ax, bw_adjust=0.5)
sns.kdeplot(in_sample[is_same==0], label='Different Genes', ax=ax, bw_adjust=0.5)
ax.set_xlabel("Probability guides target the same gene"); ax.legend()
plt.tight_layout();

# %%
RASGuideMap
# Out:
#       symbol1  geneid1  rank1 symbol2  geneid2  rank2                 gRNA1  \
# 0       AAVS1       17      5   ABCB7       22      4  AGAGCCACATTAACCGGCCC
# 1       AAVS1       17      5   ABCB7       22      6  AGAGCCACATTAACCGGCCC
# 2       AAVS1       17      5   ABCF1       23      2  AGAGCCACATTAACCGGCCC
# 3       AAVS1       17      5   ABCF1       23      4  AGAGCCACATTAACCGGCCC
# 4       AAVS1       17      5    ABL1       25      2  AGAGCCACATTAACCGGCCC
# ...       ...      ...    ...     ...      ...    ...                   ...
# 84195   YWHAZ     7534      3   YWHAG     7532      6  TGTGACTGATCGACAATCCC
# 84196     YY1     7528      1   AAVS1       17      2  GTCGGGTCGTCGGTGACCAG
# 84197     YY1     7528      5   AAVS1       17      2  AGATATTGACCATGAGACAG
# 84198  ZNF143     7702      1   AAVS1       17      2  TGTTACGCTGTGCTTGACAG
# 84199  ZNF143     7702      3   AAVS1       17      2  GGAATGACAGAGTTTCCTGG
#
#                       gRNA2    gRNA2_reverse_comp GuideTargetSymbol  \
# 0      TCACAGTTGCAGTCACACGG  CCGTGTGACTGCAACTGTGA             ABCB7
# 1      GCTCGCCAGTCAGGGAATTG  CAATTCCCTGACTGGCGAGC             ABCB7
# 2      GATGGAGTATGAGCGCCAAG  CTTGGCGCTCATACTCCATC             ABCF1
# 3      GAGATACCCGAAAAGGCAGG  CCTGCCTTTTCGGGTATCTC             ABCF1
# 4      GCAAGGTACTCACAGCCCCA  TGGGGCTGTGAGTACCTTGC              ABL1
# ...                     ...                   ...               ...
# 84195  GAATGAGCCACTGTCGAATG  CATTCGACAGTGGCTCATTC       YWHAZ_YWHAG
# 84196  AGGGAGACATCCGTCGGAGA  TCTCCGACGGATGTCTCCCT               YY1
# 84197  AGGGAGACATCCGTCGGAGA  TCTCCGACGGATGTCTCCCT               YY1
# 84198  AGGGAGACATCCGTCGGAGA  TCTCCGACGGATGTCTCCCT            ZNF143
# 84199  AGGGAGACATCCGTCGGAGA  TCTCCGACGGATGTCTCCCT            ZNF143
#
#                GuideLabel GuideTargetLabel  RAS-pDNA DropReasonsParalog
# 0       AAVS1_L5_ABCB7_R4      AAVS1_ABCB7    2799.0                NaN
# 1       AAVS1_L5_ABCB7_R6      AAVS1_ABCB7    2236.0                NaN
# 2       AAVS1_L5_ABCF1_R2      AAVS1_ABCF1    2033.0                NaN
# 3       AAVS1_L5_ABCF1_R4      AAVS1_ABCF1    1951.0                NaN
# 4        AAVS1_L5_ABL1_R2       AAVS1_ABL1    2996.0                NaN
# ...                   ...              ...       ...                ...
# 84195   YWHAZ_L3_YWHAG_R6      YWHAZ_YWHAG    2988.0                NaN
# 84196     YY1_L1_AAVS1_R2        YY1_AAVS1    2470.0                NaN
# 84197     YY1_L5_AAVS1_R2        YY1_AAVS1    2988.0                NaN
# 84198  ZNF143_L1_AAVS1_R2     ZNF143_AAVS1    4121.0                NaN
# 84199  ZNF143_L3_AAVS1_R2     ZNF143_AAVS1    3235.0                NaN
#
# [84200 rows x 14 columns]

# %%
gene_indexed = RASGuideMap.set_index('GuideTargetSymbol').GuideLabel.drop_duplicates()
gene_indexed = gene_indexed.loc[~gene_indexed.index.str.contains('_')]

# %%
gene_indexed
# Out:
# GuideTargetSymbol
# ABCB7      AAVS1_L5_ABCB7_R4
# ABCB7      AAVS1_L5_ABCB7_R6
# ABCF1      AAVS1_L5_ABCF1_R2
# ABCF1      AAVS1_L5_ABCF1_R4
# ABL1        AAVS1_L5_ABL1_R2
#                  ...
# YWHAZ      YWHAZ_L3_AAVS1_R2
# YY1          YY1_L1_AAVS1_R2
# YY1          YY1_L5_AAVS1_R2
# ZNF143    ZNF143_L1_AAVS1_R2
# ZNF143    ZNF143_L3_AAVS1_R2
# Name: GuideLabel, Length: 1832, dtype: object

# %%
full_lfc_seq_sgrna
# Out:
#                     SNU1079_250x-Cas9VY-RAS-RepNA-P5(D25)  \
# AAVS1_L5_ABCB7_R4                                0.320506
# AAVS1_L5_ABCB7_R6                                0.496441
# AAVS1_L5_ABCF1_R2                               -0.724443
# AAVS1_L5_ABCF1_R4                               -0.699099
# AAVS1_L5_ABL1_R2                                -0.351240
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                               -0.584299
# YY1_L1_AAVS1_R2                                  0.847267
# YY1_L5_AAVS1_R2                                 -2.135959
# ZNF143_L1_AAVS1_R2                               0.095897
# ZNF143_L3_AAVS1_R2                              -0.003424
#
#                     COLO678_250x-Cas9VY-RAS-RepNA-P5(D25)  \
# AAVS1_L5_ABCB7_R4                               -1.215063
# AAVS1_L5_ABCB7_R6                               -0.369926
# AAVS1_L5_ABCF1_R2                               -1.128686
# AAVS1_L5_ABCF1_R4                               -0.471743
# AAVS1_L5_ABL1_R2                                -0.060319
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                0.186924
# YY1_L1_AAVS1_R2                                 -1.974867
# YY1_L5_AAVS1_R2                                 -2.800872
# ZNF143_L1_AAVS1_R2                               0.238440
# ZNF143_L3_AAVS1_R2                               0.048295
#
#                     SNU410_125x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                              -1.887259
# AAVS1_L5_ABCB7_R6                              -1.622404
# AAVS1_L5_ABCF1_R2                              -1.923262
# AAVS1_L5_ABCF1_R4                              -0.277124
# AAVS1_L5_ABL1_R2                                0.432999
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                               0.119841
# YY1_L1_AAVS1_R2                                -1.926342
# YY1_L5_AAVS1_R2                                 0.474428
# ZNF143_L1_AAVS1_R2                             -0.932681
# ZNF143_L3_AAVS1_R2                              0.243178
#
#                     BXPC3_125x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                             -0.092759
# AAVS1_L5_ABCB7_R6                             -1.257312
# AAVS1_L5_ABCF1_R2                             -1.549053
# AAVS1_L5_ABCF1_R4                             -0.808366
# AAVS1_L5_ABL1_R2                               0.427382
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                             -0.708058
# YY1_L1_AAVS1_R2                               -1.162057
# YY1_L5_AAVS1_R2                               -1.039493
# ZNF143_L1_AAVS1_R2                            -0.096000
# ZNF143_L3_AAVS1_R2                             0.292613
#
#                     SNU478_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                              -3.381782
# AAVS1_L5_ABCB7_R6                              -3.058258
# AAVS1_L5_ABCF1_R2                              -1.556103
# AAVS1_L5_ABCF1_R4                              -0.844040
# AAVS1_L5_ABL1_R2                                0.083181
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                               0.288461
# YY1_L1_AAVS1_R2                                -2.680997
# YY1_L5_AAVS1_R2                                -0.347029
# ZNF143_L1_AAVS1_R2                             -0.919968
# ZNF143_L3_AAVS1_R2                              0.351822
#
#                     HCT15_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                             -2.385718
# AAVS1_L5_ABCB7_R6                             -2.578195
# AAVS1_L5_ABCF1_R2                             -2.223404
# AAVS1_L5_ABCF1_R4                             -1.184928
# AAVS1_L5_ABL1_R2                               0.600650
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                             -0.260412
# YY1_L1_AAVS1_R2                               -1.753728
# YY1_L5_AAVS1_R2                               -2.462128
# ZNF143_L1_AAVS1_R2                             0.049109
# ZNF143_L3_AAVS1_R2                            -0.581039
#
#                     COLO205_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                               -1.168285
# AAVS1_L5_ABCB7_R6                               -1.152475
# AAVS1_L5_ABCF1_R2                               -0.485253
# AAVS1_L5_ABCF1_R4                               -0.927157
# AAVS1_L5_ABL1_R2                                 0.245901
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                               -1.215913
# YY1_L1_AAVS1_R2                                 -0.974585
# YY1_L5_AAVS1_R2                                 -1.762002
# ZNF143_L1_AAVS1_R2                               0.347280
# ZNF143_L3_AAVS1_R2                              -0.282561
#
#                     HPAFII_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                              -1.097117
# AAVS1_L5_ABCB7_R6                              -2.723202
# AAVS1_L5_ABCF1_R2                              -2.556904
# AAVS1_L5_ABCF1_R4                               0.503536
# AAVS1_L5_ABL1_R2                                1.791978
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                              -1.724956
# YY1_L1_AAVS1_R2                                -0.926840
# YY1_L5_AAVS1_R2                                -2.075527
# ZNF143_L1_AAVS1_R2                             -1.421597
# ZNF143_L3_AAVS1_R2                              0.171741
#
#                     BXPC3_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                             -0.962688
# AAVS1_L5_ABCB7_R6                             -0.681319
# AAVS1_L5_ABCF1_R2                             -0.837522
# AAVS1_L5_ABCF1_R4                             -0.346238
# AAVS1_L5_ABL1_R2                               0.224708
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                             -0.079980
# YY1_L1_AAVS1_R2                               -1.432425
# YY1_L5_AAVS1_R2                               -0.796579
# ZNF143_L1_AAVS1_R2                            -0.578764
# ZNF143_L3_AAVS1_R2                             0.081446
#
#                     BXPC3_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                             -0.746954
# AAVS1_L5_ABCB7_R6                             -1.051416
# AAVS1_L5_ABCF1_R2                             -1.116777
# AAVS1_L5_ABCF1_R4                             -1.357289
# AAVS1_L5_ABL1_R2                               0.153785
# ...                                                 ...
# YWHAZ_L3_YWHAG_R6                             -0.863023
# YY1_L1_AAVS1_R2                               -1.047984
# YY1_L5_AAVS1_R2                               -0.501975
# ZNF143_L1_AAVS1_R2                             0.053541
# ZNF143_L3_AAVS1_R2                            -0.085295
#
#                     SNU410_500x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                              -2.246071
# AAVS1_L5_ABCB7_R6                              -1.179728
# AAVS1_L5_ABCF1_R2                              -0.884972
# AAVS1_L5_ABCF1_R4                              -0.543560
# AAVS1_L5_ABL1_R2                                0.117539
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                               0.485510
# YY1_L1_AAVS1_R2                                -1.503502
# YY1_L5_AAVS1_R2                                -1.026923
# ZNF143_L1_AAVS1_R2                             -1.372325
# ZNF143_L3_AAVS1_R2                             -0.526133
#
#                     SNU410_250x-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                              -2.768708
# AAVS1_L5_ABCB7_R6                              -2.737557
# AAVS1_L5_ABCF1_R2                              -1.625692
# AAVS1_L5_ABCF1_R4                              -1.677822
# AAVS1_L5_ABL1_R2                                0.333323
# ...                                                  ...
# YWHAZ_L3_YWHAG_R6                               1.235671
# YY1_L1_AAVS1_R2                                -1.049061
# YY1_L5_AAVS1_R2                                -1.252655
# ZNF143_L1_AAVS1_R2                             -0.699990
# ZNF143_L3_AAVS1_R2                             -0.643152
#
#                     IPC298_500x-Cas9311-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                               -3.345454
# AAVS1_L5_ABCB7_R6                               -3.092226
# AAVS1_L5_ABCF1_R2                               -1.722554
# AAVS1_L5_ABCF1_R4                                0.887870
# AAVS1_L5_ABL1_R2                                 0.707999
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                               -1.875335
# YY1_L1_AAVS1_R2                                 -1.162405
# YY1_L5_AAVS1_R2                                 -1.629107
# ZNF143_L1_AAVS1_R2                              -1.793939
# ZNF143_L3_AAVS1_R2                               0.339901
#
#                     IPC298_250x-Cas9311-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                               -3.381782
# AAVS1_L5_ABCB7_R6                               -3.092226
# AAVS1_L5_ABCF1_R2                               -2.187412
# AAVS1_L5_ABCF1_R4                               -0.732345
# AAVS1_L5_ABL1_R2                                 0.781422
# ...                                                   ...
# YWHAZ_L3_YWHAG_R6                                1.006723
# YY1_L1_AAVS1_R2                                 -2.141664
# YY1_L5_AAVS1_R2                                 -1.262105
# ZNF143_L1_AAVS1_R2                              -0.816708
# ZNF143_L3_AAVS1_R2                               0.646292
#
#                     PANC1-Cas9VY-RAS-RepNA-P4(D21)  \
# AAVS1_L5_ABCB7_R4                        -1.217206
# AAVS1_L5_ABCB7_R6                        -0.642117
# AAVS1_L5_ABCF1_R2                         0.017822
# AAVS1_L5_ABCF1_R4                        -0.032012
# AAVS1_L5_ABL1_R2                         -0.029653
# ...                                            ...
# YWHAZ_L3_YWHAG_R6                        -0.141413
# YY1_L1_AAVS1_R2                          -2.424001
# YY1_L5_AAVS1_R2                          -1.514905
# ZNF143_L1_AAVS1_R2                       -0.194830
# ZNF143_L3_AAVS1_R2                       -0.466771
#
#                     PANC0203-Cas9VY-RAS-RepNA-P4(D21)
# AAVS1_L5_ABCB7_R4                           -1.298764
# AAVS1_L5_ABCB7_R6                           -0.321086
# AAVS1_L5_ABCF1_R2                           -1.562556
# AAVS1_L5_ABCF1_R4                           -0.738690
# AAVS1_L5_ABL1_R2                             0.865324
# ...                                               ...
# YWHAZ_L3_YWHAG_R6                            0.479160
# YY1_L1_AAVS1_R2                             -0.961267
# YY1_L5_AAVS1_R2                             -1.175441
# ZNF143_L1_AAVS1_R2                          -0.393861
# ZNF143_L3_AAVS1_R2                          -0.130885
#
# [84200 rows x 16 columns]

# %%
agreement = []
features = []
for i, gene in enumerate(gene_indexed.index.unique()):
    if not i % 1000 and i > 0:
        print('%i genes complete' % i)
    guides = gene_indexed.loc[[gene]]
    if len(guides) < 2:
        continue
    for j, guide1 in enumerate(guides[:-1]):
        for guide2 in guides[j+1:]:
            assert guide1 != guide2, "%r %s %s" % (guides, guide1, guide2)
            features.append(get_metrics(
                full_lfc_seq_sgrna.loc[guide1], 
                full_lfc_seq_sgrna.loc[guide2]
            ))
            agreement.append({'gene': gene, 'guide1': guide1, 'guide2': guide2})
# Out:
# /home/ubuntu/miniconda3/envs/paralog/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/ubuntu/miniconda3/envs/paralog/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /tmp/ipykernel_10416/348653938.py:19: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   spearman = spearmanr(a, b)[0]
# /home/ubuntu/miniconda3/envs/paralog/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/ubuntu/miniconda3/envs/paralog/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /tmp/ipykernel_10416/348653938.py:19: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   spearman = spearmanr(a, b)[0]

# %%
# Collect results
features = pd.DataFrame(features)
agreement = pd.DataFrame(agreement)
agreement['agreement'] = model.predict_proba(features.values, )[:, 1]

# %%
agreement_per_guide = pd.melt(agreement, id_vars=['gene', 'agreement'], value_vars=['guide1', 'guide2'], var_name='guide_type', value_name='guide')
agreement_per_guide = agreement_per_guide.groupby(['guide']).mean('agreement').sort_values(['agreement'])

# %%
low_agreement_guides = agreement_per_guide.loc[agreement_per_guide['agreement'] < 0.4].index

# %%
agreement_per_guide.loc[agreement_per_guide['agreement'] < 0.4]
# Out:
#                     agreement
# guide
# SPACA7_L9_AAVS1_R2   0.214543
# AAVS1_L5_AHCY_R6     0.219147
# TAF1_L3_AAVS1_R2     0.244985
# KSR2_L5_AAVS1_R2     0.251691
# RET_L3_AAVS1_R2      0.256854
# ...                       ...
# AAVS1_L5_CHAT_R0     0.398212
# KDR_L5_AAVS1_R2      0.398431
# RANBP2_L1_AAVS1_R2   0.398871
# GLT6D1_L3_AAVS1_R2   0.399451
# AAVS1_L5_MOGAT3_R6   0.399479
#
# [200 rows x 1 columns]

# %%
def conditional_replace(value):
    if value is None or str(value)=='nan':
        return 'AgreementScore<0.4'
    return value+';'+'AgreementScore<0.4'

# %%
RASGuideMap.loc[RASGuideMap['GuideLabel'].isin(low_agreement_guides), 'DropReasonsRAS'] = RASGuideMap.loc[RASGuideMap['GuideLabel'].isin(low_agreement_guides), 'DropReasonsRAS'].apply(conditional_replace)

# %%
# Saving out
chronos.write_hdf5(full_lfc_seq_sgrna, "RASFullLfcSgrnaSeq.hdf5")
chronos.write_hdf5(norm_readcounts, "RASFullNormCountsSgrnaSeq.hdf5")
RASGuideMap.to_csv("RASFullGuideMap.csv", index=False)
agreement.to_csv("RASGuideAgreementScore.csv", index=False)

# %%
import os
from taigapy import create_taiga_client_v3
from taigapy.client_v3 import UploadedFile, LocalFormat, TaigaReference
tc = create_taiga_client_v3()
version = tc.update_dataset('rasscreen02062025-6bdb', 
                            "Uploading Full norm counts, full LFC matrix and full guide map with annotation; \n Add agreement score based on AVANA 24q2 model", 
                            additions=[
    UploadedFile('RASFullLfcSgrnaSeq', 
                 local_path=os.path.join("RASFullLfcSgrnaSeq.hdf5"), 
                 format=LocalFormat.HDF5_MATRIX),
     UploadedFile('RASFullNormCountsSgrnaSeq', 
                 local_path=os.path.join("RASFullNormCountsSgrnaSeq.hdf5"), 
                 format=LocalFormat.HDF5_MATRIX),
    UploadedFile('RASFullGuideMap', 
                 local_path=os.path.join("RASFullGuideMap.csv"), 
                 format= LocalFormat.CSV_TABLE),
    UploadedFile('RASGuideAgreementScore', 
                 local_path=os.path.join("RASGuideAgreementScore.csv"), 
                 format= LocalFormat.CSV_TABLE),
  
    ]
)
# Out:
# Created temporary upload session 57777203c8944dd4bb582fcd88223d9f
# Uploading RASFullLfcSgrnaSeq.hdf5 to S3
# Finished uploading RASFullLfcSgrnaSeq.hdf5 to S3
# Completed uploading RASFullLfcSgrnaSeq.hdf5 to S3
# Added RASFullLfcSgrnaSeq.hdf5 to upload session 57777203c8944dd4bb582fcd88223d9f
# Uploading RASFullNormCountsSgrnaSeq.hdf5 to S3
# Finished uploading RASFullNormCountsSgrnaSeq.hdf5 to S3
# Completed uploading RASFullNormCountsSgrnaSeq.hdf5 to S3
# Added RASFullNormCountsSgrnaSeq.hdf5 to upload session 57777203c8944dd4bb582fcd88223d9f
# Uploading RASFullGuideMap.csv to S3
# Finished uploading RASFullGuideMap.csv to S3
# Completed uploading RASFullGuideMap.csv to S3
# Added RASFullGuideMap.csv to upload session 57777203c8944dd4bb582fcd88223d9f
# Uploading RASGuideAgreementScore.csv to S3
# Finished uploading RASGuideAgreementScore.csv to S3
# Completed uploading RASGuideAgreementScore.csv to S3
# Added RASGuideAgreementScore.csv to upload session 57777203c8944dd4bb582fcd88223d9f
# Dataset created. Access it directly with this url: https://cds.team/taiga/dataset/rasscreen02062025-6bdb/5

# %% [markdown]
# # Copy number profile

# %%
#merged_gene_cn_profile = tc.get(name='cn-latest-d8d4', version=46, file='merged_gene_cn_profile')
OmicsCNGene = tc.get(name='internal-24q4-8c04', version=77, file='OmicsCNGene')
#OmicsDefaultModelProfiles = tc.get(name='internal-24q4-8c04', version=77, file='OmicsDefaultModelProfiles')

# %%
RASGuideMap['GuideTargetSymbol'].drop_duplicates()
# Out:
# 0              ABCB7
# 2              ABCF1
# 4               ABL1
# 6             ACTL7A
# 8             ACTL7B
#             ...
# 83899     YWHAZ_TSC2
# 83901    YWHAZ_WWTR1
# 83903     YWHAZ_YAP1
# 83905    YWHAZ_YWHAE
# 83907    YWHAZ_YWHAG
# Name: GuideTargetSymbol, Length: 21050, dtype: object

# %%
targets = RASGuideMap['GuideTargetSymbol'].drop_duplicates()
targets_RAS = targets[targets.str.contains("_")]
targets_gene = targets[~targets.str.contains("_")]
targets_RAS = pd.DataFrame({
    'RAS': targets_RAS,
    'GeneA':  targets_RAS.str.split('_').str[0],
    'GeneB':   targets_RAS.str.split('_').str[1],
})

# %%
targets_RAS #used to be 7916
# Out:
#                RAS  GeneA  GeneB
# 941      AKT1_AKT2   AKT1   AKT2
# 943      AKT1_AKT3   AKT1   AKT3
# 945       AKT1_ALK   AKT1    ALK
# 947      AKT1_ARAF   AKT1   ARAF
# 949      AKT1_BRAF   AKT1   BRAF
# ...            ...    ...    ...
# 83899   YWHAZ_TSC2  YWHAZ   TSC2
# 83901  YWHAZ_WWTR1  YWHAZ  WWTR1
# 83903   YWHAZ_YAP1  YWHAZ   YAP1
# 83905  YWHAZ_YWHAE  YWHAZ  YWHAE
# 83907  YWHAZ_YWHAG  YWHAZ  YWHAG
#
# [20592 rows x 3 columns]

# %%
OmicsCNGene = OmicsCNGene.copy()
OmicsCNGene.columns = pd.Series(OmicsCNGene.columns).apply(lambda x: x.split(' ')[0])
OmicsCNGene = OmicsCNGene.T
OmicsCNGene = OmicsCNGene.reset_index()
OmicsCNGene = OmicsCNGene.drop_duplicates(subset='index')
OmicsCNGene = OmicsCNGene.set_index('index')

targets_RAS_GeneA = targets_RAS.merge(OmicsCNGene, how = 'left', left_on='GeneA', right_index=True)
targets_RAS_GeneB = targets_RAS.merge(OmicsCNGene, how = 'left', left_on='GeneB', right_index=True)

# %%
targets_RAS_GeneA
# Out:
#                RAS  GeneA  GeneB  ACH-000628  ACH-002999  ACH-001394  \
# 941      AKT1_AKT2   AKT1   AKT2    0.650881    1.032738    0.972168
# 943      AKT1_AKT3   AKT1   AKT3    0.650881    1.032738    0.972168
# 945       AKT1_ALK   AKT1    ALK    0.650881    1.032738    0.972168
# 947      AKT1_ARAF   AKT1   ARAF    0.650881    1.032738    0.972168
# 949      AKT1_BRAF   AKT1   BRAF    0.650881    1.032738    0.972168
# ...            ...    ...    ...         ...         ...         ...
# 83899   YWHAZ_TSC2  YWHAZ   TSC2    1.338678    1.063292    1.944028
# 83901  YWHAZ_WWTR1  YWHAZ  WWTR1    1.338678    1.063292    1.944028
# 83903   YWHAZ_YAP1  YWHAZ   YAP1    1.338678    1.063292    1.944028
# 83905  YWHAZ_YWHAE  YWHAZ  YWHAE    1.338678    1.063292    1.944028
# 83907  YWHAZ_YWHAG  YWHAZ  YWHAG    1.338678    1.063292    1.944028
#
#        ACH-001973  ACH-001163  ACH-000814  ACH-000886  ...  ACH-000236  \
# 941      0.975487    0.987842    0.997668    0.867692  ...    0.939869
# 943      0.975487    0.987842    0.997668    0.867692  ...    0.939869
# 945      0.975487    0.987842    0.997668    0.867692  ...    0.939869
# 947      0.975487    0.987842    0.997668    0.867692  ...    0.939869
# 949      0.975487    0.987842    0.997668    0.867692  ...    0.939869
# ...           ...         ...         ...         ...  ...         ...
# 83899    1.008685    1.288836    1.045982    1.404326  ...    1.685214
# 83901    1.008685    1.288836    1.045982    1.404326  ...    1.685214
# 83903    1.008685    1.288836    1.045982    1.404326  ...    1.685214
# 83905    1.008685    1.288836    1.045982    1.404326  ...    1.685214
# 83907    1.008685    1.288836    1.045982    1.404326  ...    1.685214
#
#        ACH-002177  ACH-002760  ACH-002163  ACH-002316  ACH-001039  ACH-003477  \
# 941      1.433379    1.001799    1.045322    1.430884    0.645022    0.727059
# 943      1.433379    1.001799    1.045322    1.430884    0.645022    0.727059
# 945      1.433379    1.001799    1.045322    1.430884    0.645022    0.727059
# 947      1.433379    1.001799    1.045322    1.430884    0.645022    0.727059
# 949      1.433379    1.001799    1.045322    1.430884    0.645022    0.727059
# ...           ...         ...         ...         ...         ...         ...
# 83899    0.936632    1.547253    1.275427    0.965529    1.123957    1.085870
# 83901    0.936632    1.547253    1.275427    0.965529    1.123957    1.085870
# 83903    0.936632    1.547253    1.275427    0.965529    1.123957    1.085870
# 83905    0.936632    1.547253    1.275427    0.965529    1.123957    1.085870
# 83907    0.936632    1.547253    1.275427    0.965529    1.123957    1.085870
#
#        ACH-001971  ACH-002761  ACH-002276
# 941      1.177049    0.694255    1.020494
# 943      1.177049    0.694255    1.020494
# 945      1.177049    0.694255    1.020494
# 947      1.177049    0.694255    1.020494
# 949      1.177049    0.694255    1.020494
# ...           ...         ...         ...
# 83899    1.108575    1.072454    0.998080
# 83901    1.108575    1.072454    0.998080
# 83903    1.108575    1.072454    0.998080
# 83905    1.108575    1.072454    0.998080
# 83907    1.108575    1.072454    0.998080
#
# [20592 rows x 2398 columns]

# %%
OmicsCNGeneRAS = targets_RAS_GeneA.filter(regex='^ACH') + targets_RAS_GeneB.filter(regex='^ACH')
OmicsCNGeneRAS.index = targets_RAS['RAS']
OmicsCNGeneRAS = OmicsCNGeneRAS.T

# %%
OmicsCNGeneSingleGene = pd.DataFrame({'GuideTargetSymbol': targets_gene}).merge(
    OmicsCNGene, how = 'left', left_on = 'GuideTargetSymbol', right_index=True
).set_index("GuideTargetSymbol")

# %%
OmicsCNGeneRASV2 = pd.concat([OmicsCNGeneSingleGene, OmicsCNGeneRAS.T], axis=0)
OmicsCNGeneRASV2 = OmicsCNGeneRASV2.T

# %%
OmicsCNGeneRASV2 = OmicsCNGeneRASV2.fillna(1)

# %%
chronos.write_hdf5(OmicsCNGeneRASV2, "OmicsCNGeneFullProfileRASV2.hdf5")

# %%
version = tc.update_dataset('rasscreen02062025-6bdb', 
                            "Uploading OmicsCNGeneFullProfileRASV2", 
                            additions=[
    UploadedFile('OmicsCNGeneFullProfileRASV2', 
                 local_path=os.path.join("OmicsCNGeneFullProfileRASV2.hdf5"), 
                 format=LocalFormat.HDF5_MATRIX)
                            ]
                           )
# Out:
# Created temporary upload session 1be48a4ea2f04096a062f37d39a68c76
# Uploading OmicsCNGeneFullProfileRASV2.hdf5 to S3
# Finished uploading OmicsCNGeneFullProfileRASV2.hdf5 to S3
# Completed uploading OmicsCNGeneFullProfileRASV2.hdf5 to S3
# Added OmicsCNGeneFullProfileRASV2.hdf5 to upload session 1be48a4ea2f04096a062f37d39a68c76
# Dataset created. Access it directly with this url: https://cds.team/taiga/dataset/rasscreen02062025-6bdb/9
